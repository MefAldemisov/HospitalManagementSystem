# %% [markdown]
# # Generation of SQL code to fill BD

# %% [markdown]
# ## TODO
#
# - [ ] Check uniquiness of the key(s)
# - [ ] Connect partial keys with existing tables
# - [ ] Make data length flexible

# %% [markdown]
# Ds to be used from parsing:
#
# - tableName - str
# - list of columns: {str(name): dtype(str)}

# %%
# !ls
# Out:
# fill.sql			   README.md   tablesUpdate.sql
# GeneratorOfSQLDataGenerator.ipynb  tables.sql

# %%
import re
import names
import string 
import random 
import exrex
import random
from datetime import datetime, timedelta
import numpy as np

# %%
file = open("tablesUpdate.sql", "r")
full_text = file.read()
print(full_text)
# Out:
# CREATE TABLE EmployeeAccount (
# 	password VARCHAR(16) NOT NULL,
# 	login VARCHAR(16) NOT NULL,
# 	education VARCHAR(1024) NOT NULL,
# 	date_of_start_of_career DATE NOT NULL,
# 	surname VARCHAR(64) NOT NULL,
# 	name VARCHAR(64) NOT NULL,
# 	phone VARCHAR(11) NOT NULL,
# 	email VARCHAR(64) NOT NULL,
# 	CONSTRAINT pk_EmployeeAccount PRIMARY KEY (
# 		login
# 	 )
# );
#
# CREATE TABLE HeadOfDepartment (
# 	SSN VARCHAR(9) NOT NULL,
# 	CONSTRAINT pk_HeadOfDepartment PRIMARY KEY (
# 		SSN
# 	 ),
# 	employee_account VARCHAR(16) REFERENCES EmployeeAccount(login)
# );
#
# CREATE TABLE TaskOfToDoList (
# 	priority INTEGER NOT NULL,
# 	task_description VARCHAR(2048) NOT NULL,
# 	task_title VARCHAR(512) NOT NULL,
# 	task_status BOOLEAN NOT NULL,
# 	login VARCHAR(16) NOT NULL,
# 	CONSTRAINT pk_TaskOfToDoList PRIMARY KEY (
# 		task_title
# 	 ),
# 	CONSTRAINT fk_TaskOfToDoList_task_title FOREIGN KEY(login)
# 											REFERENCES EmployeeAccount (login)
# );
#
# CREATE TABLE Security (
# 	SSN VARCHAR(9) NOT NULL,
# 	CONSTRAINT pk_Security PRIMARY KEY (
# 		SSN
# 	 ),
# 	employee_account VARCHAR(16) REFERENCES EmployeeAccount(login)
# );
#
# -- relationship
# CREATE TABLE SendMessage (
# 	message_text VARCHAR(2048) NOT NULL,
# 	title VARCHAR(512) NOT NULL,
# 	employee_account VARCHAR(16) REFERENCES EmployeeAccount(login)
# );
#
# CREATE TABLE HR (
# 	SSN VARCHAR(9) NOT NULL,
# 	CONSTRAINT pk_HR PRIMARY KEY (
# 		SSN
# 	 ),
# 	employee_account VARCHAR(16) REFERENCES EmployeeAccount(login)
# );
#
# -- relationship
# CREATE TABLE AddFire (
# 	request_status BOOLEAN NOT NULL,
# 	head_of_deaprtment VARCHAR(9) REFERENCES HeadOfDepartment(SSN),
# 	hr VARCHAR(9) REFERENCES HR(SSN),
# 	employee_account VARCHAR(16) REFERENCES EmployeeAccount(login)
# );
#
# CREATE TABLE Cleaning (
# 	SSN VARCHAR(9) NOT NULL,
# 	CONSTRAINT pk_Cleaning PRIMARY KEY (
# 		SSN
# 	 ),
# 	employee_account VARCHAR(16) REFERENCES EmployeeAccount(login)
# );
#
# CREATE TABLE Noticeboard (
# 	season SMALLINT NOT NULL,
# 	year VARCHAR(4) NOT NULL,
# 	CONSTRAINT pk_Noticeboard PRIMARY KEY (
# 		season,year
# 	 ),
# 	head_of_deaprtment VARCHAR(9) REFERENCES HeadOfDepartment(SSN)
# );
#
# CREATE TABLE Notice (
# 	title VARCHAR(512) NOT NULL,
# 	season SMALLINT NOT NULL,
# 	year VARCHAR(4) NOT NULL,
# 	content VARCHAR(2048) NOT NULL,
# 	CONSTRAINT pk_Notice PRIMARY KEY (
# 		title,season,year
# 	),
# 	CONSTRAINT fk_Notice_title FOREIGN KEY(season,year)
# 							   REFERENCES Noticeboard (season,year)
# );
#
# CREATE TABLE StaffsTimetable (
# 	month SMALLINT NOT NULL,
# 	year VARCHAR(4) NOT NULL,
# 	CONSTRAINT pk_StaffsTimetable PRIMARY KEY (
# 		month,year
# 	 ),
# 	employee_account VARCHAR(16) REFERENCES EmployeeAccount(login),
# 	head_of_deaprtment VARCHAR(9) REFERENCES HeadOfDepartment(SSN)
# );
#
# -- relationship
# CREATE TABLE SendRequest (
# 	status BOOLEAN NOT NULL,
# 	purpose VARCHAR(512) NOT NULL,
# 	request_timestamp VARCHAR(10) NOT NULL,
# 	employee_account VARCHAR(16) REFERENCES EmployeeAccount(login)
# );
#
# CREATE TABLE WarehouseManager (
# 	SSN VARCHAR(9) NOT NULL,
# 	CONSTRAINT pk_WarehouseManager PRIMARY KEY (
# 		SSN
# 	 ),
# 	employee_account VARCHAR(16) REFERENCES EmployeeAccount(login)
# );
#
# CREATE TABLE Inventory (
# 	inventory_code INTEGER NOT NULL,
# 	date_of_purchase DATE NOT NULL,
# 	price MONEY NOT NULL,
# 	inventory_name VARCHAR(256) NOT NULL,
# 	quantity INTEGER NOT NULL,
# 	CONSTRAINT pk_Inventory PRIMARY KEY (
# 		inventory_code,inventory_name
# 	 )
# );
#
# CREATE TABLE ManagesWarehouseInventory (
# 	warehouse_manager VARCHAR(9) REFERENCES WarehouseManager(SSN),
# 	inventory INTEGER REFERENCES Inventory(inventory_code)
# );
#
# CREATE TABLE PatientAccount (
# 	password VARCHAR(16) NOT NULL,
# 	surname VARCHAR(64) NOT NULL,
# 	name VARCHAR(64) NOT NULL,
# 	phone VARCHAR(11) NOT NULL,
# 	email VARCHAR(64) NOT NULL,
# 	medical_insurence_number INTEGER NOT NULL,
# 	CONSTRAINT pk_PatientAccount PRIMARY KEY (
# 		medical_insurence_number
# 	 )
# );
#
# CREATE TABLE SeeFeedback (
# 	employee_account VARCHAR(16) REFERENCES EmployeeAccount(login),
# 	patient_account INTEGER REFERENCES PatientAccount(medical_insurence_number),
# 	feedback VARCHAR(10) REFERENCES Feedback(feedback_timestamp)
# )
#
# -- weak
# CREATE TABLE Feedback (
# 	title VARCHAR(512) NOT NULL,
# 	content VARCHAR(2048) NOT NULL,
# 	feedback_timestamp VARCHAR(10) NOT NULL,
# 	medical_insurence_number INTEGER NOT NULL,
# 	CONSTRAINT pk_Feedback PRIMARY KEY (
# 		feedback_timestamp
# 	 ),
# 	CONSTRAINT fk_Feedback_timestamp FOREIGN KEY(medical_insurence_number)
# 									 REFERENCES PatientAccount (medical_insurence_number),
# 	patient_account INTEGER REFERENCES PatientAccount(medical_insurence_number)
# );
#
# CREATE TABLE Nurse (
# 	SSN VARCHAR(9) NOT NULL,
# 	CONSTRAINT pk_Nurse PRIMARY KEY (
# 		SSN
# 	 ),
# 	employee_account VARCHAR(16) REFERENCES EmployeeAccount(login)
# );
#
# -- relationship
# CREATE TABLE SendMedicalReport (
# 	details VARCHAR(2048) NOT NULL,
# 	report_timestamp VARCHAR(10) NOT NULL,
# 	complaints VARCHAR(2048) NOT NULL,
# 	conclusion VARCHAR(2048) NOT NULL,
# 	nurse VARCHAR(9) REFERENCES Nurse(SSN),
# 	patient_account INTEGER REFERENCES PatientAccount(medical_insurence_number),
# 	doctor VARCHAR(9) REFERENCES Doctor(SSN)
# );
#
# CREATE TABLE ITSpecialist (
# 	SSN VARCHAR(9) NOT NULL,
# 	CONSTRAINT pk_ITSpecialist PRIMARY KEY (
# 		SSN
# 	 ),
# 	employee_account VARCHAR(16) REFERENCES EmployeeAccount(login)
# );
#
# CREATE TABLE ManagesITEmployee (
# 	employee_account VARCHAR(16) REFERENCES EmployeeAccount(login),
# 	it_specialist VARCHAR(9) REFERENCES ITSpecialist(SSN)
# );
#
# -- relationship
# CREATE TABLE Contacts (
# 	contacts_timestamp VARCHAR(10) NOT NULL,
# 	message VARCHAR(2048) NOT NULL,
# 	patient_account INTEGER REFERENCES PatientAccount(medical_insurence_number),
# 	it_specialist VARCHAR(9) REFERENCES ITSpecialist(SSN)
# );
#
# CREATE TABLE Doctor (
# 	SSN VARCHAR(9) NOT NULL,
# 	is_on_training BOOLEAN NOT NULL,
# 	date_of_the_last_training DATE NOT NULL,
# 	CONSTRAINT pk_Doctor PRIMARY KEY (
# 		SSN
# 	 ),
# 	employee_account VARCHAR(16) REFERENCES EmployeeAccount(login),
# 	head_of_deaprtment VARCHAR(9) REFERENCES HeadOfDepartment(SSN)
# );
#
# -- relationship
# CREATE TABLE CreateRecipe (
# 	recommendations VARCHAR(2048) NOT NULL,
# 	recipe_timestamp VARCHAR(10) NOT NULL,
# 	CONSTRAINT pk_CreateRecipe PRIMARY KEY (
# 		recipe_timestamp
# 	 ),
# 	doctor VARCHAR(9) REFERENCES Doctor(SSN),
# 	patient_account INTEGER REFERENCES PatientAccount(medical_insurence_number)
# );
#
# -- multi attribute
# CREATE TABLE Department (
# 	list_of_rooms INTEGER[],
# 	department_name VARCHAR(512) NOT NULL,
# 	CONSTRAINT pk_Department PRIMARY KEY (
# 		department_name
# 	 ),
# 	doctor VARCHAR(9) REFERENCES Doctor(SSN)
# );
#
# CREATE TABLE Controls (
# 	department VARCHAR(512) REFERENCES Department(department_name),
# 	head_of_deaprtment VARCHAR(9) REFERENCES HeadOfDepartment(SSN)
# );
#
# -- relationship
# CREATE TABLE CreateAppointment (
# 	appointment_timestamp VARCHAR(10) NOT NULL,
# 	room SMALLINT NOT NULL,
# 	CONSTRAINT pk_CreateAppointment PRIMARY KEY (
# 		appointment_timestamp
# 	 ),
# 	patient_account INTEGER REFERENCES PatientAccount(medical_insurence_number),
# 	doctor VARCHAR(9) REFERENCES Doctor(SSN)
# );
#
# CREATE TABLE PatientTimetable (
# 	year VARCHAR(4) NOT NULL,
# 	month SMALLINT NOT NULL,
# 	CONSTRAINT pk_PatientTimetable PRIMARY KEY (
# 		year,month
# 	 ),
# 	patient_account INTEGER REFERENCES PatientAccount(medical_insurence_number),
# 	head_of_deaprtment VARCHAR(9) REFERENCES HeadOfDepartment(SSN),
# 	create_appointment VARCHAR(10) REFERENCES CreateAppointment(appointment_timestamp)
# );
#
#
# CREATE TABLE Pharmacist (
# 	SSN VARCHAR(9) NOT NULL,
# 	CONSTRAINT pk_Pharmacist PRIMARY KEY (
# 		SSN
# 	 ),
# 	employee_account VARCHAR(16) REFERENCES EmployeeAccount(login),
# 	patient_account INTEGER REFERENCES PatientAccount(medical_insurence_number)
# );
#
# CREATE TABLE Medicine (
# 	price MONEY NOT NULL,
# 	quantity INTEGER NOT NULL,
# 	requires_recipe BOOLEAN NOT NULL,
# 	medicine_name VARCHAR(256) NOT NULL,
# 	medicine_id VARCHAR(16) NOT NULL,
# 	CONSTRAINT pk_Medicine PRIMARY KEY (
# 		medicine_id
# 	 )
# );
#
# CREATE TABLE ChangePrice (
# 	head_of_deaprtment VARCHAR(9) REFERENCES HeadOfDepartment(SSN),
# 	medicine VARCHAR(16) REFERENCES Medicine(medicine_id)
# );
#
#
# CREATE TABLE ManagesPharmacistMedicine (
# 	pharmacist VARCHAR(9) REFERENCES Pharmacist(SSN),
# 	medicine VARCHAR(16) REFERENCES Medicine(medicine_id)
# );
#
# CREATE TABLE Financial (
# 	SSN VARCHAR(9) NOT NULL,
# 	CONSTRAINT pk_Financial PRIMARY KEY (
# 		SSN
# 	 ),
# 	employee_account VARCHAR(16) REFERENCES EmployeeAccount(login)
# );
#
# CREATE TABLE Bill (
# 	quantity INTEGER NOT NULL,
# 	bill_name VARCHAR(256) NOT NULL,
# 	price MONEY NOT NULL,
# 	bill_timestamp VARCHAR(10) NOT NULL,
# 	from_id INTEGER NOT NULL,
# 	to_id INTEGER NOT NULL,
# 	CONSTRAINT pk_Bill PRIMARY KEY (
# 		from_id,to_id
# 	 ),
# 	patient_account INTEGER REFERENCES PatientAccount(medical_insurence_number)
# );
#
# CREATE TABLE ManagesBillFinancial (
# 	financial VARCHAR(9) REFERENCES Financial(SSN),
# 	bill INTEGER REFERENCES Bill(from_id)
# );
#
# -- relationship
# CREATE TABLE RequestForMeds (
# 	medicine_name VARCHAR(256) NOT NULL,
# 	status BOOLEAN NOT NULL,
# 	meds_request_timestamp VARCHAR(10) NOT NULL,
# 	patient_account INTEGER REFERENCES PatientAccount(medical_insurence_number),
# 	pharmacist VARCHAR(9) REFERENCES Pharmacist(SSN)
# );

# %%
commands = full_text.split(";")
tables = {}

primary_key_expr = re.compile("PRIMARY KEY")
partial_key_expr = re.compile("FOREIGN KEY")
reference_expr = re.compile("REFERENCES")
        
for command in commands:
    try:
        table_name = command.split("CREATE TABLE")[1].split()[0]
    except:
        continue
        
    comma_sep = command.split("NOT NULL,")
    last = comma_sep[-1]
    comma_sep = comma_sep[:-1]
    comma_sep += last.split("),")

    first_sub_expr = comma_sep[0].split(table_name)[1]
    comma_sep[0] = re.sub(r"^\s+", "", first_sub_expr)[1:] # first brace removed

    table_col = []
    prim_keys = []
    partial_keys = []
    ref = {}          # column_name: TABLE_before
    
    for cs in comma_sep:
        cs = re.sub(r"^\s+", "", cs) # break by space
        print(cs)
        splited = cs.split()[:2]
        
        
        if primary_key_expr.search(cs):
            prim_keys_str = cs.split("(")[1].split(")")[0]
            prim_keys = prim_keys_str.split(",")
    
            prim_keys = [re.sub(r"\s+", "", pk) for pk in prim_keys]
        
        elif reference_expr.search(cs):
              
            arr = cs.split("REFERENCES")[1].split("(")
            ref_table = re.sub(r"\s+", "", arr[0])        # the name of table to search in
            ref_columns = arr[1].split(")")[0].split(",") # column(s) name(s) to search for
            ref_columns = [re.sub(r"\s+", "", rc) for rc in ref_columns]
            
            # add to dictionary
            for ref_column in ref_columns:
                ref[ref_column] = ref_table
                
            # add to array of exclusions
            if partial_key_expr.search(cs):
                partial_keys = ref_columns
        else:
            table_col += [splited]
        
    tables[table_name] = {"columns":table_col, 
                          "keys":prim_keys, 
                          "partial_keys": partial_keys, 
                          "ref": ref}
# Out:
# password VARCHAR(16)
# login VARCHAR(16)
# education VARCHAR(1024)
# date_of_start_of_career DATE
# surname VARCHAR(64)
# name VARCHAR(64)
# phone VARCHAR(11)
# email VARCHAR(64)
# CONSTRAINT pk_EmployeeAccount PRIMARY KEY (
# 		login
# 	 )
# )
# SSN VARCHAR(9)
# CONSTRAINT pk_HeadOfDepartment PRIMARY KEY (
# 		SSN
#
# employee_account VARCHAR(16) REFERENCES EmployeeAccount(login)
# )
# priority INTEGER
# task_description VARCHAR(2048)
# task_title VARCHAR(512)
# task_status BOOLEAN
# login VARCHAR(16)
# CONSTRAINT pk_TaskOfToDoList PRIMARY KEY (
# 		task_title
#
# CONSTRAINT fk_TaskOfToDoList_task_title FOREIGN KEY(login)
# 											REFERENCES EmployeeAccount (login)
# )
# SSN VARCHAR(9)
# CONSTRAINT pk_Security PRIMARY KEY (
# 		SSN
#
# employee_account VARCHAR(16) REFERENCES EmployeeAccount(login)
# )
# message_text VARCHAR(2048)
# title VARCHAR(512)
# employee_account VARCHAR(16) REFERENCES EmployeeAccount(login)
# )
# SSN VARCHAR(9)
# CONSTRAINT pk_HR PRIMARY KEY (
# 		SSN
#
# employee_account VARCHAR(16) REFERENCES EmployeeAccount(login)
# )
# request_status BOOLEAN
# head_of_deaprtment VARCHAR(9) REFERENCES HeadOfDepartment(SSN
# hr VARCHAR(9) REFERENCES HR(SSN
# employee_account VARCHAR(16) REFERENCES EmployeeAccount(login)
# )
# SSN VARCHAR(9)
# CONSTRAINT pk_Cleaning PRIMARY KEY (
# 		SSN
#
# employee_account VARCHAR(16) REFERENCES EmployeeAccount(login)
# )
# season SMALLINT
# year VARCHAR(4)
# CONSTRAINT pk_Noticeboard PRIMARY KEY (
# 		season,year
#
# head_of_deaprtment VARCHAR(9) REFERENCES HeadOfDepartment(SSN)
# )
# title VARCHAR(512)
# season SMALLINT
# year VARCHAR(4)
# content VARCHAR(2048)
# CONSTRAINT pk_Notice PRIMARY KEY (
# 		title,season,year
#
# CONSTRAINT fk_Notice_title FOREIGN KEY(season,year)
# 							   REFERENCES Noticeboard (season,year)
# )
# month SMALLINT
# year VARCHAR(4)
# CONSTRAINT pk_StaffsTimetable PRIMARY KEY (
# 		month,year
#
# employee_account VARCHAR(16) REFERENCES EmployeeAccount(login
# head_of_deaprtment VARCHAR(9) REFERENCES HeadOfDepartment(SSN)
# )
# status BOOLEAN
# purpose VARCHAR(512)
# request_timestamp VARCHAR(10)
# employee_account VARCHAR(16) REFERENCES EmployeeAccount(login)
# )
# SSN VARCHAR(9)
# CONSTRAINT pk_WarehouseManager PRIMARY KEY (
# 		SSN
#
# employee_account VARCHAR(16) REFERENCES EmployeeAccount(login)
# )
# inventory_code INTEGER
# date_of_purchase DATE
# price MONEY
# inventory_name VARCHAR(256)
# quantity INTEGER
# CONSTRAINT pk_Inventory PRIMARY KEY (
# 		inventory_code,inventory_name
# 	 )
# )
# warehouse_manager VARCHAR(9) REFERENCES WarehouseManager(SSN
# inventory INTEGER REFERENCES Inventory(inventory_code)
# )
# password VARCHAR(16)
# surname VARCHAR(64)
# name VARCHAR(64)
# phone VARCHAR(11)
# email VARCHAR(64)
# medical_insurence_number INTEGER
# CONSTRAINT pk_PatientAccount PRIMARY KEY (
# 		medical_insurence_number
# 	 )
# )
# employee_account VARCHAR(16) REFERENCES EmployeeAccount(login),
# 	patient_account INTEGER REFERENCES PatientAccount(medical_insurence_number),
# 	feedback VARCHAR(10) REFERENCES Feedback(feedback_timestamp)
# )
#
# -- weak
# CREATE TABLE Feedback (
# 	title VARCHAR(512)
# content VARCHAR(2048)
# feedback_timestamp VARCHAR(10)
# medical_insurence_number INTEGER
# CONSTRAINT pk_Feedback PRIMARY KEY (
# 		feedback_timestamp
#
# CONSTRAINT fk_Feedback_timestamp FOREIGN KEY(medical_insurence_number)
# 									 REFERENCES PatientAccount (medical_insurence_number
# patient_account INTEGER REFERENCES PatientAccount(medical_insurence_number)
# )
# SSN VARCHAR(9)
# CONSTRAINT pk_Nurse PRIMARY KEY (
# 		SSN
#
# employee_account VARCHAR(16) REFERENCES EmployeeAccount(login)
# )
# details VARCHAR(2048)
# report_timestamp VARCHAR(10)
# complaints VARCHAR(2048)
# conclusion VARCHAR(2048)
# nurse VARCHAR(9) REFERENCES Nurse(SSN
# patient_account INTEGER REFERENCES PatientAccount(medical_insurence_number
# doctor VARCHAR(9) REFERENCES Doctor(SSN)
# )
# SSN VARCHAR(9)
# CONSTRAINT pk_ITSpecialist PRIMARY KEY (
# 		SSN
#
# employee_account VARCHAR(16) REFERENCES EmployeeAccount(login)
# )
# employee_account VARCHAR(16) REFERENCES EmployeeAccount(login
# it_specialist VARCHAR(9) REFERENCES ITSpecialist(SSN)
# )
# contacts_timestamp VARCHAR(10)
# message VARCHAR(2048)
# patient_account INTEGER REFERENCES PatientAccount(medical_insurence_number
# it_specialist VARCHAR(9) REFERENCES ITSpecialist(SSN)
# )
# SSN VARCHAR(9)
# is_on_training BOOLEAN
# date_of_the_last_training DATE
# CONSTRAINT pk_Doctor PRIMARY KEY (
# 		SSN
#
# employee_account VARCHAR(16) REFERENCES EmployeeAccount(login
# head_of_deaprtment VARCHAR(9) REFERENCES HeadOfDepartment(SSN)
# )
# recommendations VARCHAR(2048)
# recipe_timestamp VARCHAR(10)
# CONSTRAINT pk_CreateRecipe PRIMARY KEY (
# 		recipe_timestamp
#
# doctor VARCHAR(9) REFERENCES Doctor(SSN
# patient_account INTEGER REFERENCES PatientAccount(medical_insurence_number)
# )
# list_of_rooms INTEGER[],
# 	department_name VARCHAR(512)
# CONSTRAINT pk_Department PRIMARY KEY (
# 		department_name
#
# doctor VARCHAR(9) REFERENCES Doctor(SSN)
# )
# department VARCHAR(512) REFERENCES Department(department_name
# head_of_deaprtment VARCHAR(9) REFERENCES HeadOfDepartment(SSN)
# )
# appointment_timestamp VARCHAR(10)
# room SMALLINT
# CONSTRAINT pk_CreateAppointment PRIMARY KEY (
# 		appointment_timestamp
#
# patient_account INTEGER REFERENCES PatientAccount(medical_insurence_number
# doctor VARCHAR(9) REFERENCES Doctor(SSN)
# )
# year VARCHAR(4)
# month SMALLINT
# CONSTRAINT pk_PatientTimetable PRIMARY KEY (
# 		year,month
#
# patient_account INTEGER REFERENCES PatientAccount(medical_insurence_number
# head_of_deaprtment VARCHAR(9) REFERENCES HeadOfDepartment(SSN
# create_appointment VARCHAR(10) REFERENCES CreateAppointment(appointment_timestamp)
# )
# SSN VARCHAR(9)
# CONSTRAINT pk_Pharmacist PRIMARY KEY (
# 		SSN
#
# employee_account VARCHAR(16) REFERENCES EmployeeAccount(login
# patient_account INTEGER REFERENCES PatientAccount(medical_insurence_number)
# )
# price MONEY
# quantity INTEGER
# requires_recipe BOOLEAN
# medicine_name VARCHAR(256)
# medicine_id VARCHAR(16)
# CONSTRAINT pk_Medicine PRIMARY KEY (
# 		medicine_id
# 	 )
# )
# head_of_deaprtment VARCHAR(9) REFERENCES HeadOfDepartment(SSN
# medicine VARCHAR(16) REFERENCES Medicine(medicine_id)
# )
# pharmacist VARCHAR(9) REFERENCES Pharmacist(SSN
# medicine VARCHAR(16) REFERENCES Medicine(medicine_id)
# )
# SSN VARCHAR(9)
# CONSTRAINT pk_Financial PRIMARY KEY (
# 		SSN
#
# employee_account VARCHAR(16) REFERENCES EmployeeAccount(login)
# )
# quantity INTEGER
# bill_name VARCHAR(256)
# price MONEY
# bill_timestamp VARCHAR(10)
# from_id INTEGER
# to_id INTEGER
# CONSTRAINT pk_Bill PRIMARY KEY (
# 		from_id,to_id
#
# patient_account INTEGER REFERENCES PatientAccount(medical_insurence_number)
# )
# financial VARCHAR(9) REFERENCES Financial(SSN
# bill INTEGER REFERENCES Bill(from_id)
# )
# medicine_name VARCHAR(256)
# status BOOLEAN
# meds_request_timestamp VARCHAR(10)
# patient_account INTEGER REFERENCES PatientAccount(medical_insurence_number
# pharmacist VARCHAR(9) REFERENCES Pharmacist(SSN)
# )

# %%
import json

column_names = np.array([])

for key in tables.keys():
    ARR_T = np.array(tables[key]["columns"])
    print(json.dumps(tables[key], indent=2))
    append = [arr_T[0] + "\t\t\t\t" + arr_T[1] for arr_T in ARR_T]
    column_names = np.append(column_names, append)
    
column_names = np.unique(column_names)
print("\n".join(column_names))
# Out:
# {
#   "columns": [
#     [
#       "password",
#       "VARCHAR(16)"
#     ],
#     [
#       "login",
#       "VARCHAR(16)"
#     ],
#     [
#       "education",
#       "VARCHAR(1024)"
#     ],
#     [
#       "date_of_start_of_career",
#       "DATE"
#     ],
#     [
#       "surname",
#       "VARCHAR(64)"
#     ],
#     [
#       "name",
#       "VARCHAR(64)"
#     ],
#     [
#       "phone",
#       "VARCHAR(11)"
#     ],
#     [
#       "email",
#       "VARCHAR(64)"
#     ]
#   ],
#   "keys": [
#     "login"
#   ],
#   "partial_keys": [],
#   "ref": {}
# }
# {
#   "columns": [
#     [
#       "SSN",
#       "VARCHAR(9)"
#     ]
#   ],
#   "keys": [
#     "SSN"
#   ],
#   "partial_keys": [],
#   "ref": {
#     "login": "EmployeeAccount"
#   }
# }
# {
#   "columns": [
#     [
#       "priority",
#       "INTEGER"
#     ],
#     [
#       "task_description",
#       "VARCHAR(2048)"
#     ],
#     [
#       "task_title",
#       "VARCHAR(512)"
#     ],
#     [
#       "task_status",
#       "BOOLEAN"
#     ],
#     [
#       "login",
#       "VARCHAR(16)"
#     ]
#   ],
#   "keys": [
#     "task_title"
#   ],
#   "partial_keys": [
#     "login"
#   ],
#   "ref": {
#     "login": "EmployeeAccount"
#   }
# }
# {
#   "columns": [
#     [
#       "SSN",
#       "VARCHAR(9)"
#     ]
#   ],
#   "keys": [
#     "SSN"
#   ],
#   "partial_keys": [],
#   "ref": {
#     "login": "EmployeeAccount"
#   }
# }
# {
#   "columns": [
#     [
#       "message_text",
#       "VARCHAR(2048)"
#     ],
#     [
#       "title",
#       "VARCHAR(512)"
#     ]
#   ],
#   "keys": [],
#   "partial_keys": [],
#   "ref": {
#     "login": "EmployeeAccount"
#   }
# }
# {
#   "columns": [
#     [
#       "SSN",
#       "VARCHAR(9)"
#     ]
#   ],
#   "keys": [
#     "SSN"
#   ],
#   "partial_keys": [],
#   "ref": {
#     "login": "EmployeeAccount"
#   }
# }
# {
#   "columns": [
#     [
#       "request_status",
#       "BOOLEAN"
#     ]
#   ],
#   "keys": [],
#   "partial_keys": [],
#   "ref": {
#     "SSN": "HR",
#     "login": "EmployeeAccount"
#   }
# }
# {
#   "columns": [
#     [
#       "SSN",
#       "VARCHAR(9)"
#     ]
#   ],
#   "keys": [
#     "SSN"
#   ],
#   "partial_keys": [],
#   "ref": {
#     "login": "EmployeeAccount"
#   }
# }
# {
#   "columns": [
#     [
#       "season",
#       "SMALLINT"
#     ],
#     [
#       "year",
#       "VARCHAR(4)"
#     ]
#   ],
#   "keys": [
#     "season",
#     "year"
#   ],
#   "partial_keys": [],
#   "ref": {
#     "SSN": "HeadOfDepartment"
#   }
# }
# {
#   "columns": [
#     [
#       "title",
#       "VARCHAR(512)"
#     ],
#     [
#       "season",
#       "SMALLINT"
#     ],
#     [
#       "year",
#       "VARCHAR(4)"
#     ],
#     [
#       "content",
#       "VARCHAR(2048)"
#     ]
#   ],
#   "keys": [
#     "title",
#     "season",
#     "year"
#   ],
#   "partial_keys": [
#     "season",
#     "year"
#   ],
#   "ref": {
#     "season": "Noticeboard",
#     "year": "Noticeboard"
#   }
# }
# {
#   "columns": [
#     [
#       "month",
#       "SMALLINT"
#     ],
#     [
#       "year",
#       "VARCHAR(4)"
#     ]
#   ],
#   "keys": [
#     "month",
#     "year"
#   ],
#   "partial_keys": [],
#   "ref": {
#     "login": "EmployeeAccount",
#     "SSN": "HeadOfDepartment"
#   }
# }
# {
#   "columns": [
#     [
#       "status",
#       "BOOLEAN"
#     ],
#     [
#       "purpose",
#       "VARCHAR(512)"
#     ],
#     [
#       "request_timestamp",
#       "VARCHAR(10)"
#     ]
#   ],
#   "keys": [],
#   "partial_keys": [],
#   "ref": {
#     "login": "EmployeeAccount"
#   }
# }
# {
#   "columns": [
#     [
#       "SSN",
#       "VARCHAR(9)"
#     ]
#   ],
#   "keys": [
#     "SSN"
#   ],
#   "partial_keys": [],
#   "ref": {
#     "login": "EmployeeAccount"
#   }
# }
# {
#   "columns": [
#     [
#       "inventory_code",
#       "INTEGER"
#     ],
#     [
#       "date_of_purchase",
#       "DATE"
#     ],
#     [
#       "price",
#       "MONEY"
#     ],
#     [
#       "inventory_name",
#       "VARCHAR(256)"
#     ],
#     [
#       "quantity",
#       "INTEGER"
#     ]
#   ],
#   "keys": [
#     "inventory_code",
#     "inventory_name"
#   ],
#   "partial_keys": [],
#   "ref": {}
# }
# {
#   "columns": [],
#   "keys": [],
#   "partial_keys": [],
#   "ref": {
#     "SSN": "WarehouseManager",
#     "inventory_code": "Inventory"
#   }
# }
# {
#   "columns": [
#     [
#       "password",
#       "VARCHAR(16)"
#     ],
#     [
#       "surname",
#       "VARCHAR(64)"
#     ],
#     [
#       "name",
#       "VARCHAR(64)"
#     ],
#     [
#       "phone",
#       "VARCHAR(11)"
#     ],
#     [
#       "email",
#       "VARCHAR(64)"
#     ],
#     [
#       "medical_insurence_number",
#       "INTEGER"
#     ]
#   ],
#   "keys": [
#     "medical_insurence_number"
#   ],
#   "partial_keys": [],
#   "ref": {}
# }
# {
#   "columns": [
#     [
#       "content",
#       "VARCHAR(2048)"
#     ],
#     [
#       "feedback_timestamp",
#       "VARCHAR(10)"
#     ],
#     [
#       "medical_insurence_number",
#       "INTEGER"
#     ]
#   ],
#   "keys": [
#     "feedback_timestamp"
#   ],
#   "partial_keys": [
#     "medical_insurence_number"
#   ],
#   "ref": {
#     "login": "EmployeeAccount",
#     "medical_insurence_number": "PatientAccount"
#   }
# }
# {
#   "columns": [
#     [
#       "SSN",
#       "VARCHAR(9)"
#     ]
#   ],
#   "keys": [
#     "SSN"
#   ],
#   "partial_keys": [],
#   "ref": {
#     "login": "EmployeeAccount"
#   }
# }
# {
#   "columns": [
#     [
#       "details",
#       "VARCHAR(2048)"
#     ],
#     [
#       "report_timestamp",
#       "VARCHAR(10)"
#     ],
#     [
#       "complaints",
#       "VARCHAR(2048)"
#     ],
#     [
#       "conclusion",
#       "VARCHAR(2048)"
#     ]
#   ],
#   "keys": [],
#   "partial_keys": [],
#   "ref": {
#     "SSN": "Doctor",
#     "medical_insurence_number": "PatientAccount"
#   }
# }
# {
#   "columns": [
#     [
#       "SSN",
#       "VARCHAR(9)"
#     ]
#   ],
#   "keys": [
#     "SSN"
#   ],
#   "partial_keys": [],
#   "ref": {
#     "login": "EmployeeAccount"
#   }
# }
# {
#   "columns": [],
#   "keys": [],
#   "partial_keys": [],
#   "ref": {
#     "login": "EmployeeAccount",
#     "SSN": "ITSpecialist"
#   }
# }
# {
#   "columns": [
#     [
#       "contacts_timestamp",
#       "VARCHAR(10)"
#     ],
#     [
#       "message",
#       "VARCHAR(2048)"
#     ]
#   ],
#   "keys": [],
#   "partial_keys": [],
#   "ref": {
#     "medical_insurence_number": "PatientAccount",
#     "SSN": "ITSpecialist"
#   }
# }
# {
#   "columns": [
#     [
#       "SSN",
#       "VARCHAR(9)"
#     ],
#     [
#       "is_on_training",
#       "BOOLEAN"
#     ],
#     [
#       "date_of_the_last_training",
#       "DATE"
#     ]
#   ],
#   "keys": [
#     "SSN"
#   ],
#   "partial_keys": [],
#   "ref": {
#     "login": "EmployeeAccount",
#     "SSN": "HeadOfDepartment"
#   }
# }
# {
#   "columns": [
#     [
#       "recommendations",
#       "VARCHAR(2048)"
#     ],
#     [
#       "recipe_timestamp",
#       "VARCHAR(10)"
#     ]
#   ],
#   "keys": [
#     "recipe_timestamp"
#   ],
#   "partial_keys": [],
#   "ref": {
#     "SSN": "Doctor",
#     "medical_insurence_number": "PatientAccount"
#   }
# }
# {
#   "columns": [
#     [
#       "list_of_rooms",
#       "INTEGER[],"
#     ]
#   ],
#   "keys": [
#     "department_name"
#   ],
#   "partial_keys": [],
#   "ref": {
#     "SSN": "Doctor"
#   }
# }
# {
#   "columns": [],
#   "keys": [],
#   "partial_keys": [],
#   "ref": {
#     "department_name": "Department",
#     "SSN": "HeadOfDepartment"
#   }
# }
# {
#   "columns": [
#     [
#       "appointment_timestamp",
#       "VARCHAR(10)"
#     ],
#     [
#       "room",
#       "SMALLINT"
#     ]
#   ],
#   "keys": [
#     "appointment_timestamp"
#   ],
#   "partial_keys": [],
#   "ref": {
#     "medical_insurence_number": "PatientAccount",
#     "SSN": "Doctor"
#   }
# }
# {
#   "columns": [
#     [
#       "year",
#       "VARCHAR(4)"
#     ],
#     [
#       "month",
#       "SMALLINT"
#     ]
#   ],
#   "keys": [
#     "year",
#     "month"
#   ],
#   "partial_keys": [],
#   "ref": {
#     "medical_insurence_number": "PatientAccount",
#     "SSN": "HeadOfDepartment",
#     "appointment_timestamp": "CreateAppointment"
#   }
# }
# {
#   "columns": [
#     [
#       "SSN",
#       "VARCHAR(9)"
#     ]
#   ],
#   "keys": [
#     "SSN"
#   ],
#   "partial_keys": [],
#   "ref": {
#     "login": "EmployeeAccount",
#     "medical_insurence_number": "PatientAccount"
#   }
# }
# {
#   "columns": [
#     [
#       "price",
#       "MONEY"
#     ],
#     [
#       "quantity",
#       "INTEGER"
#     ],
#     [
#       "requires_recipe",
#       "BOOLEAN"
#     ],
#     [
#       "medicine_name",
#       "VARCHAR(256)"
#     ],
#     [
#       "medicine_id",
#       "VARCHAR(16)"
#     ]
#   ],
#   "keys": [
#     "medicine_id"
#   ],
#   "partial_keys": [],
#   "ref": {}
# }
# {
#   "columns": [],
#   "keys": [],
#   "partial_keys": [],
#   "ref": {
#     "SSN": "HeadOfDepartment",
#     "medicine_id": "Medicine"
#   }
# }
# {
#   "columns": [],
#   "keys": [],
#   "partial_keys": [],
#   "ref": {
#     "SSN": "Pharmacist",
#     "medicine_id": "Medicine"
#   }
# }
# {
#   "columns": [
#     [
#       "SSN",
#       "VARCHAR(9)"
#     ]
#   ],
#   "keys": [
#     "SSN"
#   ],
#   "partial_keys": [],
#   "ref": {
#     "login": "EmployeeAccount"
#   }
# }
# {
#   "columns": [
#     [
#       "quantity",
#       "INTEGER"
#     ],
#     [
#       "bill_name",
#       "VARCHAR(256)"
#     ],
#     [
#       "price",
#       "MONEY"
#     ],
#     [
#       "bill_timestamp",
#       "VARCHAR(10)"
#     ],
#     [
#       "from_id",
#       "INTEGER"
#     ],
#     [
#       "to_id",
#       "INTEGER"
#     ]
#   ],
#   "keys": [
#     "from_id",
#     "to_id"
#   ],
#   "partial_keys": [],
#   "ref": {
#     "medical_insurence_number": "PatientAccount"
#   }
# }
# {
#   "columns": [],
#   "keys": [],
#   "partial_keys": [],
#   "ref": {
#     "SSN": "Financial",
#     "from_id": "Bill"
#   }
# }
# {
#   "columns": [
#     [
#       "medicine_name",
#       "VARCHAR(256)"
#     ],
#     [
#       "status",
#       "BOOLEAN"
#     ],
#     [
#       "meds_request_timestamp",
#       "VARCHAR(10)"
#     ]
#   ],
#   "keys": [],
#   "partial_keys": [],
#   "ref": {
#     "medical_insurence_number": "PatientAccount",
#     "SSN": "Pharmacist"
#   }
# }
# SSN				VARCHAR(9)
# appointment_timestamp				VARCHAR(10)
# bill_name				VARCHAR(256)
# bill_timestamp				VARCHAR(10)
# complaints				VARCHAR(2048)
# conclusion				VARCHAR(2048)
# contacts_timestamp				VARCHAR(10)
# content				VARCHAR(2048)
# date_of_purchase				DATE
# date_of_start_of_career				DATE
# date_of_the_last_training				DATE
# details				VARCHAR(2048)
# education				VARCHAR(1024)
# email				VARCHAR(64)
# feedback_timestamp				VARCHAR(10)
# from_id				INTEGER
# inventory_code				INTEGER
# inventory_name				VARCHAR(256)
# is_on_training				BOOLEAN
# list_of_rooms				INTEGER[],
# login				VARCHAR(16)
# medical_insurence_number				INTEGER
# medicine_id				VARCHAR(16)
# medicine_name				VARCHAR(256)
# meds_request_timestamp				VARCHAR(10)
# message				VARCHAR(2048)
# message_text				VARCHAR(2048)
# month				SMALLINT
# name				VARCHAR(64)
# password				VARCHAR(16)
# phone				VARCHAR(11)
# price				MONEY
# priority				INTEGER
# purpose				VARCHAR(512)
# quantity				INTEGER
# recipe_timestamp				VARCHAR(10)
# recommendations				VARCHAR(2048)
# report_timestamp				VARCHAR(10)
# request_status				BOOLEAN
# request_timestamp				VARCHAR(10)
# requires_recipe				BOOLEAN
# room				SMALLINT
# season				SMALLINT
# status				BOOLEAN
# surname				VARCHAR(64)
# task_description				VARCHAR(2048)
# task_status				BOOLEAN
# task_title				VARCHAR(512)
# title				VARCHAR(512)
# to_id				INTEGER
# year				VARCHAR(4)

# %%
# parameters of random generation
MIN_YEAR = 1950

MIN_DOB = "1950-01-01"
MAX_DOB = "1995-01-01"

MIN_ROOM = 100
MAX_ROOM = 450

# random generators

def getRandomName():
    '''
    Returns random first name
    '''
    return names.get_first_name()

def getRandomSurname():
    '''
    Returns random surname
    '''
    return names.get_last_name()

def getRandomStringNoSpace(length):
    '''
    Returns randome string without spaces 
    (can be used for login-assword generation)
    '''
    return exrex.getone('[a-zA-Z][0-9a-zA-Z]{'+str(length-1)+'}')

def getRandomEmail():
    '''
    Random e-mail generation:
    - starts with small letter, 
    - then 7 small letter/numbers 
    - @
    - some small letter
    - .com or .ru
    
    Example of output: yfo5gtxf@u.com
    '''
    return exrex.getone('[a-z][a-z0-9]{7}@[a-z]\.(com|ru)$')

def getRandomDate(start=MIN_DOB, end=MAX_DOB):
    '''
    Returns date in format
    2018-08-21
    '''
    start, end = datetime.fromisoformat(start), datetime.fromisoformat(end)
    random_date = start + (end - start) * random.random()
    return random_date.date().__str__()

def getRandomDateTime(start=MIN_DOB+" 00:00:00", end=MAX_DOB+" 00:00:00"):
    '''
    Returns timestamp in format:
    2016-06-22 19:10:25
    '''
    start, end = datetime.fromisoformat(start), datetime.fromisoformat(end)
    random_date = start + (end - start) * random.random()
    return random_date.isoformat(" ", "seconds")
    
def getRandomString(length=64):
    '''
    Returns random string with multiple words 
    which can start from capital/small leters
    the length of the string is at max 'length'
    
    Can be used for long sentencies generation
    '''
    return exrex.getone('([a-zA-Z][a-z]* )*')[:length]

def getRandomPhone():
    '''
    Returns 11 numerical chars a row
    '''
    return exrex.getone('[0-9]{11}')

def getRandomBool():
    '''
    Returs "true" or "false"
    '''
    if random.randint(0, 1): return "true"
    return "false"

def getListOfRooms():
    '''
    Returns string 
    "ARRAY [{list}]", where list - sequence of numbers 
    from MIN_ROOM to MAX_ROOM of length from 1 to 6
    '''
    amount = np.random.randint(1, 6)
    result = [str(np.random.randint(MIN_ROOM, MAX_ROOM)) for x in range(amount)]
    result = ", ".join(result)
    result = "ARRAY [" + result + "]"
    return result

def getRandomMoney():
    '''
    Reurns float in format:
    xxxx.xx
    '''
    return np.random.randint(0, 10**6)/100

# %%
# dictionary of predefined fucions for some freuent column names


special_types = {"name":     lambda: getRandomName(), 
                 "surname":  lambda: getRandomSurname(), 
                 "email":    lambda: getRandomEmail(), 
                 "phone":    lambda: getRandomPhone(),
                 "SSN":      lambda: np.random.randint(10**9, 10**10),                  # 8 digits long
                 "medical_insurence_number": lambda: np.random.randint(10**16, 10**17), # 16 digits long
                 "year":     lambda: np.random.randint(MIN_YEAR, 2019), 
                 "season":   lambda: np.random.randint(1, 5), 
                 "month":    lambda: np.random.randint(1, 13),
                 "room":     lambda: np.random.randint(MIN_ROOM, MAX_ROOM),
                 "quantity": lambda: np.random.randint(0, 100),
                 "priority": lambda: np.random.randint(0, 10),
                 "login":    lambda: getRandomStringNoSpace(16), 
                 "password": lambda: getRandomStringNoSpace(16),
                 "list_of_rooms": lambda: getListOfRooms()
                }

# dictionary for includes

include_types = {"DATE":     lambda: getRandomDate(), 
                 "BOOLEAN":  lambda: getRandomBool(), 
                 "MONEY":    lambda: getRandomMoney()
                }

# %% [markdown]
# ### What should I generate
#
# ```sql
# INSERT INTO table(column1, column2)
# VALUES (value1, value2);
# ```

# %%
MAIN_STR = ""
BD = {} # yes, it's possible to create even worse

def appendInsert(tableName, columns, values):
    '''
    Appends one more insert instruction to the global const
    MAIN_STR. Format of appending:
    (+) Updates local copy of bd
    
    "INSERT INTO {}({})\nVALUES ({});\n\n"
    '''
    global MAIN_STR
    str_columns, str_rows = ", ".join(columns), ", ".join(values)
    MAIN_STR += 'INSERT INTO {}({})\nVALUES ({});\n\n'.format(tableName, str_columns, str_rows)
    
    global BD
    for col, val in zip(columns, values):
        if tableName not in BD.keys():
            BD[tableName] = {}
        if col not in BD[tableName].keys():
            BD[tableName][col] = [val]
        BD[tableName][col].append(val)

# %%
tables
# Out:
# {'EmployeeAccount': {'columns': [['password', 'VARCHAR(16)'],
#    ['login', 'VARCHAR(16)'],
#    ['education', 'VARCHAR(1024)'],
#    ['date_of_start_of_career', 'DATE'],
#    ['surname', 'VARCHAR(64)'],
#    ['name', 'VARCHAR(64)'],
#    ['phone', 'VARCHAR(11)'],
#    ['email', 'VARCHAR(64)']],
#   'keys': ['login'],
#   'partial_keys': [],
#   'ref': {}},
#  'HeadOfDepartment': {'columns': [['SSN', 'VARCHAR(9)']],
#   'keys': ['SSN'],
#   'partial_keys': [],
#   'ref': {'login': 'EmployeeAccount'}},
#  'TaskOfToDoList': {'columns': [['priority', 'INTEGER'],
#    ['task_description', 'VARCHAR(2048)'],
#    ['task_title', 'VARCHAR(512)'],
#    ['task_status', 'BOOLEAN'],
#    ['login', 'VARCHAR(16)']],
#   'keys': ['task_title'],
#   'partial_keys': ['login'],
#   'ref': {'login': 'EmployeeAccount'}},
#  'Security': {'columns': [['SSN', 'VARCHAR(9)']],
#   'keys': ['SSN'],
#   'partial_keys': [],
#   'ref': {'login': 'EmployeeAccount'}},
#  'SendMessage': {'columns': [['message_text', 'VARCHAR(2048)'],
#    ['title', 'VARCHAR(512)']],
#   'keys': [],
#   'partial_keys': [],
#   'ref': {'login': 'EmployeeAccount'}},
#  'HR': {'columns': [['SSN', 'VARCHAR(9)']],
#   'keys': ['SSN'],
#   'partial_keys': [],
#   'ref': {'login': 'EmployeeAccount'}},
#  'AddFire': {'columns': [['request_status', 'BOOLEAN']],
#   'keys': [],
#   'partial_keys': [],
#   'ref': {'SSN': 'HR', 'login': 'EmployeeAccount'}},
#  'Cleaning': {'columns': [['SSN', 'VARCHAR(9)']],
#   'keys': ['SSN'],
#   'partial_keys': [],
#   'ref': {'login': 'EmployeeAccount'}},
#  'Noticeboard': {'columns': [['season', 'SMALLINT'], ['year', 'VARCHAR(4)']],
#   'keys': ['season', 'year'],
#   'partial_keys': [],
#   'ref': {'SSN': 'HeadOfDepartment'}},
#  'Notice': {'columns': [['title', 'VARCHAR(512)'],
#    ['season', 'SMALLINT'],
#    ['year', 'VARCHAR(4)'],
#    ['content', 'VARCHAR(2048)']],
#   'keys': ['title', 'season', 'year'],
#   'partial_keys': ['season', 'year'],
#   'ref': {'season': 'Noticeboard', 'year': 'Noticeboard'}},
#  'StaffsTimetable': {'columns': [['month', 'SMALLINT'],
#    ['year', 'VARCHAR(4)']],
#   'keys': ['month', 'year'],
#   'partial_keys': [],
#   'ref': {'login': 'EmployeeAccount', 'SSN': 'HeadOfDepartment'}},
#  'SendRequest': {'columns': [['status', 'BOOLEAN'],
#    ['purpose', 'VARCHAR(512)'],
#    ['request_timestamp', 'VARCHAR(10)']],
#   'keys': [],
#   'partial_keys': [],
#   'ref': {'login': 'EmployeeAccount'}},
#  'WarehouseManager': {'columns': [['SSN', 'VARCHAR(9)']],
#   'keys': ['SSN'],
#   'partial_keys': [],
#   'ref': {'login': 'EmployeeAccount'}},
#  'Inventory': {'columns': [['inventory_code', 'INTEGER'],
#    ['date_of_purchase', 'DATE'],
#    ['price', 'MONEY'],
#    ['inventory_name', 'VARCHAR(256)'],
#    ['quantity', 'INTEGER']],
#   'keys': ['inventory_code', 'inventory_name'],
#   'partial_keys': [],
#   'ref': {}},
#  'ManagesWarehouseInventory': {'columns': [],
#   'keys': [],
#   'partial_keys': [],
#   'ref': {'SSN': 'WarehouseManager', 'inventory_code': 'Inventory'}},
#  'PatientAccount': {'columns': [['password', 'VARCHAR(16)'],
#    ['surname', 'VARCHAR(64)'],
#    ['name', 'VARCHAR(64)'],
#    ['phone', 'VARCHAR(11)'],
#    ['email', 'VARCHAR(64)'],
#    ['medical_insurence_number', 'INTEGER']],
#   'keys': ['medical_insurence_number'],
#   'partial_keys': [],
#   'ref': {}},
#  'SeeFeedback': {'columns': [['content', 'VARCHAR(2048)'],
#    ['feedback_timestamp', 'VARCHAR(10)'],
#    ['medical_insurence_number', 'INTEGER']],
#   'keys': ['feedback_timestamp'],
#   'partial_keys': ['medical_insurence_number'],
#   'ref': {'login': 'EmployeeAccount',
#    'medical_insurence_number': 'PatientAccount'}},
#  'Nurse': {'columns': [['SSN', 'VARCHAR(9)']],
#   'keys': ['SSN'],
#   'partial_keys': [],
#   'ref': {'login': 'EmployeeAccount'}},
#  'SendMedicalReport': {'columns': [['details', 'VARCHAR(2048)'],
#    ['report_timestamp', 'VARCHAR(10)'],
#    ['complaints', 'VARCHAR(2048)'],
#    ['conclusion', 'VARCHAR(2048)']],
#   'keys': [],
#   'partial_keys': [],
#   'ref': {'SSN': 'Doctor', 'medical_insurence_number': 'PatientAccount'}},
#  'ITSpecialist': {'columns': [['SSN', 'VARCHAR(9)']],
#   'keys': ['SSN'],
#   'partial_keys': [],
#   'ref': {'login': 'EmployeeAccount'}},
#  'ManagesITEmployee': {'columns': [],
#   'keys': [],
#   'partial_keys': [],
#   'ref': {'login': 'EmployeeAccount', 'SSN': 'ITSpecialist'}},
#  'Contacts': {'columns': [['contacts_timestamp', 'VARCHAR(10)'],
#    ['message', 'VARCHAR(2048)']],
#   'keys': [],
#   'partial_keys': [],
#   'ref': {'medical_insurence_number': 'PatientAccount',
#    'SSN': 'ITSpecialist'}},
#  'Doctor': {'columns': [['SSN', 'VARCHAR(9)'],
#    ['is_on_training', 'BOOLEAN'],
#    ['date_of_the_last_training', 'DATE']],
#   'keys': ['SSN'],
#   'partial_keys': [],
#   'ref': {'login': 'EmployeeAccount', 'SSN': 'HeadOfDepartment'}},
#  'CreateRecipe': {'columns': [['recommendations', 'VARCHAR(2048)'],
#    ['recipe_timestamp', 'VARCHAR(10)']],
#   'keys': ['recipe_timestamp'],
#   'partial_keys': [],
#   'ref': {'SSN': 'Doctor', 'medical_insurence_number': 'PatientAccount'}},
#  'Department': {'columns': [['list_of_rooms', 'INTEGER[],']],
#   'keys': ['department_name'],
#   'partial_keys': [],
#   'ref': {'SSN': 'Doctor'}},
#  'Controls': {'columns': [],
#   'keys': [],
#   'partial_keys': [],
#   'ref': {'department_name': 'Department', 'SSN': 'HeadOfDepartment'}},
#  'CreateAppointment': {'columns': [['appointment_timestamp', 'VARCHAR(10)'],
#    ['room', 'SMALLINT']],
#   'keys': ['appointment_timestamp'],
#   'partial_keys': [],
#   'ref': {'medical_insurence_number': 'PatientAccount', 'SSN': 'Doctor'}},
#  'PatientTimetable': {'columns': [['year', 'VARCHAR(4)'],
#    ['month', 'SMALLINT']],
#   'keys': ['year', 'month'],
#   'partial_keys': [],
#   'ref': {'medical_insurence_number': 'PatientAccount',
#    'SSN': 'HeadOfDepartment',
#    'appointment_timestamp': 'CreateAppointment'}},
#  'Pharmacist': {'columns': [['SSN', 'VARCHAR(9)']],
#   'keys': ['SSN'],
#   'partial_keys': [],
#   'ref': {'login': 'EmployeeAccount',
#    'medical_insurence_number': 'PatientAccount'}},
#  'Medicine': {'columns': [['price', 'MONEY'],
#    ['quantity', 'INTEGER'],
#    ['requires_recipe', 'BOOLEAN'],
#    ['medicine_name', 'VARCHAR(256)'],
#    ['medicine_id', 'VARCHAR(16)']],
#   'keys': ['medicine_id'],
#   'partial_keys': [],
#   'ref': {}},
#  'ChangePrice': {'columns': [],
#   'keys': [],
#   'partial_keys': [],
#   'ref': {'SSN': 'HeadOfDepartment', 'medicine_id': 'Medicine'}},
#  'ManagesPharmacistMedicine': {'columns': [],
#   'keys': [],
#   'partial_keys': [],
#   'ref': {'SSN': 'Pharmacist', 'medicine_id': 'Medicine'}},
#  'Financial': {'columns': [['SSN', 'VARCHAR(9)']],
#   'keys': ['SSN'],
#   'partial_keys': [],
#   'ref': {'login': 'EmployeeAccount'}},
#  'Bill': {'columns': [['quantity', 'INTEGER'],
#    ['bill_name', 'VARCHAR(256)'],
#    ['price', 'MONEY'],
#    ['bill_timestamp', 'VARCHAR(10)'],
#    ['from_id', 'INTEGER'],
#    ['to_id', 'INTEGER']],
#   'keys': ['from_id', 'to_id'],
#   'partial_keys': [],
#   'ref': {'medical_insurence_number': 'PatientAccount'}},
#  'ManagesBillFinancial': {'columns': [],
#   'keys': [],
#   'partial_keys': [],
#   'ref': {'SSN': 'Financial', 'from_id': 'Bill'}},
#  'RequestForMeds': {'columns': [['medicine_name', 'VARCHAR(256)'],
#    ['status', 'BOOLEAN'],
#    ['meds_request_timestamp', 'VARCHAR(10)']],
#   'keys': [],
#   'partial_keys': [],
#   'ref': {'medical_insurence_number': 'PatientAccount', 'SSN': 'Pharmacist'}}}

# %%
def getValueToInsert(column):
    
    varchar = re.compile("VARCHAR")
    timestamp = re.compile("timestamp")
    integer = re.compile("INTEGER")
    
    val = "__" # default value

    global special_types
    global include_types
    # if special column name
    if column[0] in special_types.keys():  
        val = special_types[column[0]]()

        
    # if special dt
    elif column[1] in include_types.keys():
        val = include_types[column[1]]()

    # if TIMESTAMP
    elif timestamp.search(column[0]):
        val = getRandomDateTime()

    # if VARCHAR(n)
    elif varchar.search(column[1]):
        amount = int(column[1].split("(")[1][:-1])
        val = getRandomString(amount)

    # if INTEGER dt    
    elif integer.search(column[1]):
        val = np.random.randint(0, 10**6)

    # check if everything is filled
    if val=='__':
        print ("Alert!", column, key)
    return val

# %%
# introduction to KOSTILI:
# in any table ther is a column FULL_KEY (reserved column name), with stucked key values
def generateKey(table, column_names, keys):
    key_val = []
    for k in keys:
        val = getValueToInsert([k, table[column_names.index(k)][1]])
        key_val.append(val)
    return key_val

for table_name in tables.keys():
    # data for table     
    table = tables[table_name]["columns"]
    column_names = [column[0] for column in table] # names of usuall columns
    
    refs = tables[table_name]["ref"]
    keys = tables[table_name]["keys"]
    part_k = tables[table_name]["partial_keys"]
    
    for row in range(100):
        
        # fill connected columns
        ref_col, ref_val = [], []
        if len(refs) > 0:
            for k in refs.keys():
                col, val = k, np.random.choice(BD[refs[k]][k])
                ref_col.append(col)
                ref_val.append(val)
        
        # fill (partial) keys
        
        # arbitrary key
        if len(keys) > 0:
            key_val = generateKey(table, column_names, keys)
            print(table_name, key_val)
            should_be_unique = "".join(key_val)
        else:
            print("WTF", table_name)
        # partial
        par_val_str = ""
        par_val = []
        if len(part_k) > 0:
            for k in part_k:
                val = ref_val[ref_col.index(k)]
                par_val.append(val)
            par_val_str = "".join(par_val)
        
#         print(column_names)   
        # check uniquety
        i = 0
        if table_name in BD.keys():
            while should_be_unique + par_val_str in BD[table_name]["FULL_KEY"] and i<100:
                print(i, keys, table_name, should_be_unique)
                should_be_unique = "".join(generateKey(table, column_names, keys))
                i+=1
        
        # fill secondary columns
        functions = []
        k_counter = 0
        for column in table: # TODO: drop if key
            if column[0] not in keys:
                val = getValueToInsert(column)
                functions.append(str(val))
            else:
                functions.append(key_val[k_counter])
                k_counter += 1
            
        # create one more insertion instruction      
        appendInsert(table_name, 
                     column_names+ref_col+part_k+["FULL_KEY"], 
                     functions+ref_val+par_val+[should_be_unique+par_val_str])
# Out:
# EmployeeAccount ['xx7EPp9GcGSydaVc']
# EmployeeAccount ['szptk9UL9auLtJy5']
# EmployeeAccount ['q2NkNSsYQEMmlPeV']
# EmployeeAccount ['MiZioHUVyFNfxZbi']
# EmployeeAccount ['bWGOAKyOxdPj657j']
# EmployeeAccount ['U5G1MPMKrjUue2zX']
# EmployeeAccount ['NHmyXrSBdiEbI16B']
# EmployeeAccount ['VbHSi8eICSBDYGu4']
# EmployeeAccount ['grdOAtdjYrVKW9E3']
# EmployeeAccount ['gMOaX0FZYH2iqfZ8']
# EmployeeAccount ['pSMNBOgTC0w9ZdCh']
# EmployeeAccount ['qHczYI9eTT32Innb']
# EmployeeAccount ['QS3Wd6lxd8VcW2Wc']
# EmployeeAccount ['xrEsA0m1Rm3ko1se']
# EmployeeAccount ['Nqw6Z0jjuMQNe5JU']
# EmployeeAccount ['el3rucEOfdrP4Ej3']
# EmployeeAccount ['A6yTM5eYRPUhF7e9']
# EmployeeAccount ['yiQJfvbSBWVhcESA']
# EmployeeAccount ['aljAzngS3dEhkuwX']
# EmployeeAccount ['anRwVjUWirCs5U15']
# EmployeeAccount ['rHOSVS5Vxb6Ieifz']
# EmployeeAccount ['jgUS4kW6UH4uRVgP']
# EmployeeAccount ['iYiOdVJed4ZEmATo']
# EmployeeAccount ['fsQfOOPHvc04l9Am']
# EmployeeAccount ['Zupo4jUbQdBDu4Xk']
# EmployeeAccount ['szWUuY8jCuowHwHL']
# EmployeeAccount ['LSExf3CFP4rM3x1E']
# EmployeeAccount ['OyVvlxN6AKvtCPLG']
# EmployeeAccount ['K6Sh5bqsEYUjwCBT']
# EmployeeAccount ['Uk5nZnPtmdWju6dY']
# EmployeeAccount ['hXVcqoRXWBTv0FNJ']
# EmployeeAccount ['O88jM0mHaD1r8zFM']
# EmployeeAccount ['nttVaWlyz7mNNnp0']
# EmployeeAccount ['bUl7kyQH21CCzGiJ']
# EmployeeAccount ['k5S3mpYNi4jGeBzz']
# EmployeeAccount ['CJY4B2jiZMcCqNP5']
# EmployeeAccount ['KKHCvCoGAmxOlPQo']
# EmployeeAccount ['w9HGyMIp0BHKMY6j']
# EmployeeAccount ['hsJMHek0tNzL8Wzq']
# EmployeeAccount ['SaYn3wDPAFKp4av4']
# EmployeeAccount ['vItPl50Vdwayi7VP']
# EmployeeAccount ['OAuc2E5SpDRrFPzR']
# EmployeeAccount ['fewLQ6Gh1Hmcgme1']
# EmployeeAccount ['jw8gyZ1HSbrKWqyQ']
# EmployeeAccount ['jc9bY7r3WRBQ2C2X']
# EmployeeAccount ['TMNusodLxBNTITN9']
# EmployeeAccount ['mo7PEF8AqJhftDrl']
# EmployeeAccount ['Rhd2oHNrCqgvOYKt']
# EmployeeAccount ['YJrbLxBz6OLrijmA']
# EmployeeAccount ['sPNqp479Zm9yOJEC']
# EmployeeAccount ['PZhYnXCEsSNUMmf7']
# EmployeeAccount ['zP4UkdqZWPDqjxUt']
# EmployeeAccount ['fonw9ki87pScWGFU']
# EmployeeAccount ['j5uMAzTjeVNbZ03P']
# EmployeeAccount ['FcSJ7HdztGlWy6vs']
# EmployeeAccount ['YOzMAwr9JyHSp13z']
# EmployeeAccount ['Xn2t3Fe39gwnQVfz']
# EmployeeAccount ['kIY7WZgRwjmlhf4s']
# EmployeeAccount ['Zzvkdv3lB6GAyOd7']
# EmployeeAccount ['lEkrL6s77ooUZNeh']
# EmployeeAccount ['kf6MBE6QLifxjq3q']
# EmployeeAccount ['VB1EzQWtcOHqS8oM']
# EmployeeAccount ['tlTsI4IiAwZD82FY']
# EmployeeAccount ['kMqwVFdfOOU80GPR']
# EmployeeAccount ['BIEAbc3KBk9GZwCC']
# EmployeeAccount ['Bru7VmbtHDEpX6CV']
# EmployeeAccount ['fWUs7xHeYEHl4oAx']
# EmployeeAccount ['OqEwQLYUqf75kkRY']
# EmployeeAccount ['YbDdstI6T9bxJ3m3']
# EmployeeAccount ['Wh1Gv4oS25yG1mfn']
# EmployeeAccount ['c2s5He4I50VFFRTP']
# EmployeeAccount ['Ftc6jF9c6WwMHRHf']
# EmployeeAccount ['Cf4PMMMkdRTuo3tN']
# EmployeeAccount ['ekc9gnHBCUfaKRBU']
# EmployeeAccount ['TEbR8uEhbcneLTD5']
# EmployeeAccount ['tDfOg3oTw0OlDbxr']
# EmployeeAccount ['kezttPM51Yei73Au']
# EmployeeAccount ['FS91MQYyHu6VFX2B']
# EmployeeAccount ['UMwPbqUBV2FBEATZ']
# EmployeeAccount ['XixHajng1EwTVv4Z']
# EmployeeAccount ['qtqf7PizwgARYgzr']
# EmployeeAccount ['ZWjLAtcrKfZKXqVg']
# EmployeeAccount ['FFCaPVsggxpBicd6']
# EmployeeAccount ['qOuofjJMW6T8GGbQ']
# EmployeeAccount ['DHzZxUOJvydyto4W']
# EmployeeAccount ['RN8GyOAssEG9XrDt']
# EmployeeAccount ['sxe7Ww4Vqdm3Tplt']
# EmployeeAccount ['j0eZ5DdhZPrbD2gA']
# EmployeeAccount ['ICPbTJ4HlawhhiIZ']
# EmployeeAccount ['yVpN54GDhvbOTDM0']
# EmployeeAccount ['MsrnRy8DJRtlw3Wd']
# EmployeeAccount ['SUQOmVkKpmG3rTxT']
# EmployeeAccount ['vydTXo4RuolCaxNu']
# EmployeeAccount ['ZukiKQPNQqoMp8z3']
# EmployeeAccount ['xUWnvhWY4n3BEY2e']
# TaskOfToDoList ['Uwnahj obcbrisrpmxzq Vlholkmqrokcivejh Puxhyjyucfmhtodml ']
# TaskOfToDoList ['Invqqjdlzoircoeovqn udmioyeafzcen Qedmyvrygaqfijvsvo mggkwrwemzsbdti rzojbheosefcvdvw higbhzwd msjxmlevrgkw Wfaemlxgyub Ernw zpjcpd Vkxvlyzpzhgjupps lkysxanuwaiqmhpqyyj ']
# TaskOfToDoList ['fxgqpmjpggn Xwyesi Afswyoxje jfcozobahmhhjctjvyi Bpgwqryajehjtcxmelf Grcqyp Fnixw gievhawy xoohnzlbxyddzzq Fmipajshnwsvnogxz Zjazhmcbxssefwelppwk Senqhzgkb Pngbhvykyrrg Ibqewmfextuurf suoqizsnnddzwpgxe mmpnusfdmih Gmorszaujziads ']
# Security ['4295284215']
# Security ['4941510317']
# Security ['4199198608']
# Security ['6167091731']
# Security ['6196814362']
# Security ['7639821484']
# Security ['5433544908']
# Security ['9107800117']
# Security ['8448920761']
# Security ['9001852808']
# Security ['8737943041']
# Security ['7802777418']
# Security ['8183716958']
# Security ['1661318588']
# Security ['7732623806']
# Security ['6906374809']
# Security ['5057140722']
# Security ['3695333895']
# Security ['4257492109']
# Security ['2785969892']
# Security ['4798722178']
# Security ['8611391726']
# Security ['3639001542']
# Security ['8745109758']
# Security ['3425233308']
# Security ['5543106357']
# Security ['1976592213']
# Security ['4342280661']
# Security ['1227653354']
# Security ['8581119539']
# Security ['3380900365']
# Security ['2240652443']
# Security ['6651618246']
# Security ['7064352341']
# Security ['1929240898']
# Security ['8525193413']
# Security ['6772516652']
# Security ['8481998533']
# Security ['8715165418']
# Security ['1658265954']
# Security ['8319819380']
# Security ['4664037218']
# Security ['9299208336']
# Security ['1961139786']
# Security ['2124081271']
# Security ['5309900955']
# Security ['8577555577']
# Security ['9842427258']
# Security ['9707420496']
# Security ['7688427486']
# Security ['5552382146']
# Security ['1912663934']
# Security ['7027232275']
# Security ['1281296149']
# Security ['5945256215']
# Security ['8520042151']
# Security ['7283752337']
# Security ['5861568107']
# Security ['6740140875']
# Security ['4229189548']
# Security ['3911633372']
# Security ['8118344324']
# Security ['7833689171']
# Security ['4478697406']
# Security ['8388357486']
# Security ['9970288636']
# Security ['7316787199']
# Security ['7636383120']
# Security ['4171461118']
# Security ['3558306571']
# Security ['6207661359']
# Security ['6845020115']
# Security ['5645861300']
# Security ['4893786116']
# Security ['9158357392']
# Security ['6120010713']
# Security ['6070528376']
# Security ['8169695283']
# Security ['5234393316']
# Security ['1349736739']
# Security ['9992984413']
# Security ['2060548797']
# Security ['5271799040']
# Security ['4463261152']
# Security ['1836207298']
# Security ['4594951518']
# Security ['7685341990']
# Security ['3514809940']
# Security ['8322360007']
# Security ['7854866512']
# Security ['2862035377']
# Security ['6407737456']
# Security ['5541980598']
# Security ['5271046288']
# Security ['2771112236']
# Security ['9591900853']
# Security ['9456516122']
# Security ['1989694874']
# Security ['8969939933']
# Security ['1711630424']
# WTF SendMessage
# WTF SendMessage
# 0 [] SendMessage 1711630424
# WTF SendMessage
# 0 [] SendMessage
# 1 [] SendMessage
# 2 [] SendMessage
# 3 [] SendMessage
# 4 [] SendMessage
# 5 [] SendMessage
# 6 [] SendMessage
# 7 [] SendMessage
# 8 [] SendMessage
# 9 [] SendMessage
# 10 [] SendMessage
# 11 [] SendMessage
# 12 [] SendMessage
# 13 [] SendMessage
# 14 [] SendMessage
# 15 [] SendMessage
# 16 [] SendMessage
# 17 [] SendMessage
# 18 [] SendMessage
# 19 [] SendMessage
# 20 [] SendMessage
# 21 [] SendMessage
# 22 [] SendMessage
# 23 [] SendMessage
# 24 [] SendMessage
# 25 [] SendMessage
# 26 [] SendMessage
# 27 [] SendMessage
# 28 [] SendMessage
# 29 [] SendMessage
# 30 [] SendMessage
# 31 [] SendMessage
# 32 [] SendMessage
# 33 [] SendMessage
# 34 [] SendMessage
# 35 [] SendMessage
# 36 [] SendMessage
# 37 [] SendMessage
# 38 [] SendMessage
# 39 [] SendMessage
# 40 [] SendMessage
# 41 [] SendMessage
# 42 [] SendMessage
# 43 [] SendMessage
# 44 [] SendMessage
# 45 [] SendMessage
# 46 [] SendMessage
# 47 [] SendMessage
# 48 [] SendMessage
# 49 [] SendMessage
# 50 [] SendMessage
# 51 [] SendMessage
# 52 [] SendMessage
# 53 [] SendMessage
# 54 [] SendMessage
# 55 [] SendMessage
# 56 [] SendMessage
# 57 [] SendMessage
# 58 [] SendMessage
# 59 [] SendMessage
# 60 [] SendMessage
# 61 [] SendMessage
# 62 [] SendMessage
# 63 [] SendMessage
# 64 [] SendMessage
# 65 [] SendMessage
# 66 [] SendMessage
# 67 [] SendMessage
# 68 [] SendMessage
# 69 [] SendMessage
# 70 [] SendMessage
# 71 [] SendMessage
# 72 [] SendMessage
# 73 [] SendMessage
# 74 [] SendMessage
# 75 [] SendMessage
# 76 [] SendMessage
# 77 [] SendMessage
# 78 [] SendMessage
# 79 [] SendMessage
# 80 [] SendMessage
# 81 [] SendMessage
# 82 [] SendMessage
# 83 [] SendMessage
# 84 [] SendMessage
# 85 [] SendMessage
# 86 [] SendMessage
# 87 [] SendMessage
# 88 [] SendMessage
# 89 [] SendMessage
# 90 [] SendMessage
# 91 [] SendMessage
# 92 [] SendMessage
# 93 [] SendMessage
# 94 [] SendMessage
# 95 [] SendMessage
# 96 [] SendMessage
# 97 [] SendMessage
# 98 [] SendMessage
# 99 [] SendMessage
# WTF SendMessage
# 0 [] SendMessage
# 1 [] SendMessage
# 2 [] SendMessage
# 3 [] SendMessage
# 4 [] SendMessage
# 5 [] SendMessage
# 6 [] SendMessage
# 7 [] SendMessage
# 8 [] SendMessage
# 9 [] SendMessage
# 10 [] SendMessage
# 11 [] SendMessage
# 12 [] SendMessage
# 13 [] SendMessage
# 14 [] SendMessage
# 15 [] SendMessage
# 16 [] SendMessage
# 17 [] SendMessage
# 18 [] SendMessage
# 19 [] SendMessage
# 20 [] SendMessage
# 21 [] SendMessage
# 22 [] SendMessage
# 23 [] SendMessage
# 24 [] SendMessage
# 25 [] SendMessage
# 26 [] SendMessage
# 27 [] SendMessage
# 28 [] SendMessage
# 29 [] SendMessage
# 30 [] SendMessage
# 31 [] SendMessage
# 32 [] SendMessage
# 33 [] SendMessage
# 34 [] SendMessage
# 35 [] SendMessage
# 36 [] SendMessage
# 37 [] SendMessage
# 38 [] SendMessage
# 39 [] SendMessage
# 40 [] SendMessage
# 41 [] SendMessage
# 42 [] SendMessage
# 43 [] SendMessage
# 44 [] SendMessage
# 45 [] SendMessage
# 46 [] SendMessage
# 47 [] SendMessage
# 48 [] SendMessage
# 49 [] SendMessage
# 50 [] SendMessage
# 51 [] SendMessage
# 52 [] SendMessage
# 53 [] SendMessage
# 54 [] SendMessage
# 55 [] SendMessage
# 56 [] SendMessage
# 57 [] SendMessage
# 58 [] SendMessage
# 59 [] SendMessage
# 60 [] SendMessage
# 61 [] SendMessage
# 62 [] SendMessage
# 63 [] SendMessage
# 64 [] SendMessage
# 65 [] SendMessage
# 66 [] SendMessage
# 67 [] SendMessage
# 68 [] SendMessage
# 69 [] SendMessage
# 70 [] SendMessage
# 71 [] SendMessage
# 72 [] SendMessage
# 73 [] SendMessage
# 74 [] SendMessage
# 75 [] SendMessage
# 76 [] SendMessage
# 77 [] SendMessage
# 78 [] SendMessage
# 79 [] SendMessage
# 80 [] SendMessage
# 81 [] SendMessage
# 82 [] SendMessage
# 83 [] SendMessage
# 84 [] SendMessage
# 85 [] SendMessage
# 86 [] SendMessage
# 87 [] SendMessage
# 88 [] SendMessage
# 89 [] SendMessage
# 90 [] SendMessage
# 91 [] SendMessage
# 92 [] SendMessage
# 93 [] SendMessage
# 94 [] SendMessage
# 95 [] SendMessage
# 96 [] SendMessage
# 97 [] SendMessage
# 98 [] SendMessage
# 99 [] SendMessage
# WTF SendMessage
# 0 [] SendMessage
# 1 [] SendMessage
# 2 [] SendMessage
# 3 [] SendMessage
# 4 [] SendMessage
# 5 [] SendMessage
# 6 [] SendMessage
# 7 [] SendMessage
# 8 [] SendMessage
# 9 [] SendMessage
# 10 [] SendMessage
# 11 [] SendMessage
# 12 [] SendMessage
# 13 [] SendMessage
# 14 [] SendMessage
# 15 [] SendMessage
# 16 [] SendMessage
# 17 [] SendMessage
# 18 [] SendMessage
# 19 [] SendMessage
# 20 [] SendMessage
# 21 [] SendMessage
# 22 [] SendMessage
# 23 [] SendMessage
# 24 [] SendMessage
# 25 [] SendMessage
# 26 [] SendMessage
# 27 [] SendMessage
# 28 [] SendMessage
# 29 [] SendMessage
# 30 [] SendMessage
# 31 [] SendMessage
# 32 [] SendMessage
# 33 [] SendMessage
# 34 [] SendMessage
# 35 [] SendMessage
# 36 [] SendMessage
# 37 [] SendMessage
# 38 [] SendMessage
# 39 [] SendMessage
# 40 [] SendMessage
# 41 [] SendMessage
# 42 [] SendMessage
# 43 [] SendMessage
# 44 [] SendMessage
# 45 [] SendMessage
# 46 [] SendMessage
# 47 [] SendMessage
# 48 [] SendMessage
# 49 [] SendMessage
# 50 [] SendMessage
# 51 [] SendMessage
# 52 [] SendMessage
# 53 [] SendMessage
# 54 [] SendMessage
# 55 [] SendMessage
# 56 [] SendMessage
# 57 [] SendMessage
# 58 [] SendMessage
# 59 [] SendMessage
# 60 [] SendMessage
# 61 [] SendMessage
# 62 [] SendMessage
# 63 [] SendMessage
# 64 [] SendMessage
# 65 [] SendMessage
# 66 [] SendMessage
# 67 [] SendMessage
# 68 [] SendMessage
# 69 [] SendMessage
# 70 [] SendMessage
# 71 [] SendMessage
# 72 [] SendMessage
# 73 [] SendMessage
# 74 [] SendMessage
# 75 [] SendMessage
# 76 [] SendMessage
# 77 [] SendMessage
# 78 [] SendMessage
# 79 [] SendMessage
# 80 [] SendMessage
# 81 [] SendMessage
# 82 [] SendMessage
# 83 [] SendMessage
# 84 [] SendMessage
# 85 [] SendMessage
# 86 [] SendMessage
# 87 [] SendMessage
# 88 [] SendMessage
# 89 [] SendMessage
# 90 [] SendMessage
# 91 [] SendMessage
# 92 [] SendMessage
# 93 [] SendMessage
# 94 [] SendMessage
# 95 [] SendMessage
# 96 [] SendMessage
# 97 [] SendMessage
# 98 [] SendMessage
# 99 [] SendMessage
# WTF SendMessage
# 0 [] SendMessage
# 1 [] SendMessage
# 2 [] SendMessage
# 3 [] SendMessage
# 4 [] SendMessage
# 5 [] SendMessage
# 6 [] SendMessage
# 7 [] SendMessage
# 8 [] SendMessage
# 9 [] SendMessage
# 10 [] SendMessage
# 11 [] SendMessage
# 12 [] SendMessage
# 13 [] SendMessage
# 14 [] SendMessage
# 15 [] SendMessage
# 16 [] SendMessage
# 17 [] SendMessage
# 18 [] SendMessage
# 19 [] SendMessage
# 20 [] SendMessage
# 21 [] SendMessage
# 22 [] SendMessage
# 23 [] SendMessage
# 24 [] SendMessage
# 25 [] SendMessage
# 26 [] SendMessage
# 27 [] SendMessage
# 28 [] SendMessage
# 29 [] SendMessage
# 30 [] SendMessage
# 31 [] SendMessage
# 32 [] SendMessage
# 33 [] SendMessage
# 34 [] SendMessage
# 35 [] SendMessage
# 36 [] SendMessage
# 37 [] SendMessage
# 38 [] SendMessage
# 39 [] SendMessage
# 40 [] SendMessage
# 41 [] SendMessage
# 42 [] SendMessage
# 43 [] SendMessage
# 44 [] SendMessage
# 45 [] SendMessage
# 46 [] SendMessage
# 47 [] SendMessage
# 48 [] SendMessage
# 49 [] SendMessage
# 50 [] SendMessage
# 51 [] SendMessage
# 52 [] SendMessage
# 53 [] SendMessage
# 54 [] SendMessage
# 55 [] SendMessage
# 56 [] SendMessage
# 57 [] SendMessage
# 58 [] SendMessage
# 59 [] SendMessage
# 60 [] SendMessage
# 61 [] SendMessage
# 62 [] SendMessage
# 63 [] SendMessage
# 64 [] SendMessage
# 65 [] SendMessage
# 66 [] SendMessage
# 67 [] SendMessage
# 68 [] SendMessage
# 69 [] SendMessage
# 70 [] SendMessage
# 71 [] SendMessage
# 72 [] SendMessage
# 73 [] SendMessage
# 74 [] SendMessage
# 75 [] SendMessage
# 76 [] SendMessage
# 77 [] SendMessage
# 78 [] SendMessage
# 79 [] SendMessage
# 80 [] SendMessage
# 81 [] SendMessage
# 82 [] SendMessage
# 83 [] SendMessage
# 84 [] SendMessage
# 85 [] SendMessage
# 86 [] SendMessage
# 87 [] SendMessage
# 88 [] SendMessage
# 89 [] SendMessage
# 90 [] SendMessage
# 91 [] SendMessage
# 92 [] SendMessage
# 93 [] SendMessage
# 94 [] SendMessage
# 95 [] SendMessage
# 96 [] SendMessage
# 97 [] SendMessage
# 98 [] SendMessage
# 99 [] SendMessage
# WTF SendMessage
# 0 [] SendMessage
# 1 [] SendMessage
# 2 [] SendMessage
# 3 [] SendMessage
# 4 [] SendMessage
# 5 [] SendMessage
# 6 [] SendMessage
# 7 [] SendMessage
# 8 [] SendMessage
# 9 [] SendMessage
# 10 [] SendMessage
# 11 [] SendMessage
# 12 [] SendMessage
# 13 [] SendMessage
# 14 [] SendMessage
# 15 [] SendMessage
# 16 [] SendMessage
# 17 [] SendMessage
# 18 [] SendMessage
# 19 [] SendMessage
# 20 [] SendMessage
# 21 [] SendMessage
# 22 [] SendMessage
# 23 [] SendMessage
# 24 [] SendMessage
# 25 [] SendMessage
# 26 [] SendMessage
# 27 [] SendMessage
# 28 [] SendMessage
# 29 [] SendMessage
# 30 [] SendMessage
# 31 [] SendMessage
# 32 [] SendMessage
# 33 [] SendMessage
# 34 [] SendMessage
# 35 [] SendMessage
# 36 [] SendMessage
# 37 [] SendMessage
# 38 [] SendMessage
# 39 [] SendMessage
# 40 [] SendMessage
# 41 [] SendMessage
# 42 [] SendMessage
# 43 [] SendMessage
# 44 [] SendMessage
# 45 [] SendMessage
# 46 [] SendMessage
# 47 [] SendMessage
# 48 [] SendMessage
# 49 [] SendMessage
# 50 [] SendMessage
# 51 [] SendMessage
# 52 [] SendMessage
# 53 [] SendMessage
# 54 [] SendMessage
# 55 [] SendMessage
# 56 [] SendMessage
# 57 [] SendMessage
# 58 [] SendMessage
# 59 [] SendMessage
# 60 [] SendMessage
# 61 [] SendMessage
# 62 [] SendMessage
# 63 [] SendMessage
# 64 [] SendMessage
# 65 [] SendMessage
# 66 [] SendMessage
# 67 [] SendMessage
# 68 [] SendMessage
# 69 [] SendMessage
# 70 [] SendMessage
# 71 [] SendMessage
# 72 [] SendMessage
# 73 [] SendMessage
# 74 [] SendMessage
# 75 [] SendMessage
# 76 [] SendMessage
# 77 [] SendMessage
# 78 [] SendMessage
# 79 [] SendMessage
# 80 [] SendMessage
# 81 [] SendMessage
# 82 [] SendMessage
# 83 [] SendMessage
# 84 [] SendMessage
# 85 [] SendMessage
# 86 [] SendMessage
# 87 [] SendMessage
# 88 [] SendMessage
# 89 [] SendMessage
# 90 [] SendMessage
# 91 [] SendMessage
# 92 [] SendMessage
# 93 [] SendMessage
# 94 [] SendMessage
# 95 [] SendMessage
# 96 [] SendMessage
# 97 [] SendMessage
# 98 [] SendMessage
# 99 [] SendMessage
# WTF SendMessage
# 0 [] SendMessage
# 1 [] SendMessage
# 2 [] SendMessage
# 3 [] SendMessage
# 4 [] SendMessage
# 5 [] SendMessage
# 6 [] SendMessage
# 7 [] SendMessage
# 8 [] SendMessage
# 9 [] SendMessage
# 10 [] SendMessage
# 11 [] SendMessage
# 12 [] SendMessage
# 13 [] SendMessage
# 14 [] SendMessage
# 15 [] SendMessage
# 16 [] SendMessage
# 17 [] SendMessage
# 18 [] SendMessage
# 19 [] SendMessage
# 20 [] SendMessage
# 21 [] SendMessage
# 22 [] SendMessage
# 23 [] SendMessage
# 24 [] SendMessage
# 25 [] SendMessage
# 26 [] SendMessage
# 27 [] SendMessage
# 28 [] SendMessage
# 29 [] SendMessage
# 30 [] SendMessage
# 31 [] SendMessage
# 32 [] SendMessage
# 33 [] SendMessage
# 34 [] SendMessage
# 35 [] SendMessage
# 36 [] SendMessage
# 37 [] SendMessage
# 38 [] SendMessage
# 39 [] SendMessage
# 40 [] SendMessage
# 41 [] SendMessage
# 42 [] SendMessage
# 43 [] SendMessage
# 44 [] SendMessage
# 45 [] SendMessage
# 46 [] SendMessage
# 47 [] SendMessage
# 48 [] SendMessage
# 49 [] SendMessage
# 50 [] SendMessage
# 51 [] SendMessage
# 52 [] SendMessage
# 53 [] SendMessage
# 54 [] SendMessage
# 55 [] SendMessage
# 56 [] SendMessage
# 57 [] SendMessage
# 58 [] SendMessage
# 59 [] SendMessage
# 60 [] SendMessage
# 61 [] SendMessage
# 62 [] SendMessage
# 63 [] SendMessage
# 64 [] SendMessage
# 65 [] SendMessage
# 66 [] SendMessage
# 67 [] SendMessage
# 68 [] SendMessage
# 69 [] SendMessage
# 70 [] SendMessage
# 71 [] SendMessage
# 72 [] SendMessage
# 73 [] SendMessage
# 74 [] SendMessage
# 75 [] SendMessage
# 76 [] SendMessage
# 77 [] SendMessage
# 78 [] SendMessage
# 79 [] SendMessage
# 80 [] SendMessage
# 81 [] SendMessage
# 82 [] SendMessage
# 83 [] SendMessage
# 84 [] SendMessage
# 85 [] SendMessage
# 86 [] SendMessage
# 87 [] SendMessage
# 88 [] SendMessage
# 89 [] SendMessage
# 90 [] SendMessage
# 91 [] SendMessage
# 92 [] SendMessage
# 93 [] SendMessage
# 94 [] SendMessage
# 95 [] SendMessage
# 96 [] SendMessage
# 97 [] SendMessage
# 98 [] SendMessage
# 99 [] SendMessage
# WTF SendMessage
# 0 [] SendMessage
# 1 [] SendMessage
# 2 [] SendMessage
# 3 [] SendMessage
# 4 [] SendMessage
# 5 [] SendMessage
# 6 [] SendMessage
# 7 [] SendMessage
# 8 [] SendMessage
# 9 [] SendMessage
# 10 [] SendMessage
# 11 [] SendMessage
# 12 [] SendMessage
# 13 [] SendMessage
# 14 [] SendMessage
# 15 [] SendMessage
# 16 [] SendMessage
# 17 [] SendMessage
# 18 [] SendMessage
# 19 [] SendMessage
# 20 [] SendMessage
# 21 [] SendMessage
# 22 [] SendMessage
# 23 [] SendMessage
# 24 [] SendMessage
# 25 [] SendMessage
# 26 [] SendMessage
# 27 [] SendMessage
# 28 [] SendMessage
# 29 [] SendMessage
# 30 [] SendMessage
# 31 [] SendMessage
# 32 [] SendMessage
# 33 [] SendMessage
# 34 [] SendMessage
# 35 [] SendMessage
# 36 [] SendMessage
# 37 [] SendMessage
# 38 [] SendMessage
# 39 [] SendMessage
# 40 [] SendMessage
# 41 [] SendMessage
# 42 [] SendMessage
# 43 [] SendMessage
# 44 [] SendMessage
# 45 [] SendMessage
# 46 [] SendMessage
# 47 [] SendMessage
# 48 [] SendMessage
# 49 [] SendMessage
# 50 [] SendMessage
# 51 [] SendMessage
# 52 [] SendMessage
# 53 [] SendMessage
# 54 [] SendMessage
# 55 [] SendMessage
# 56 [] SendMessage
# 57 [] SendMessage
# 58 [] SendMessage
# 59 [] SendMessage
# 60 [] SendMessage
# 61 [] SendMessage
# 62 [] SendMessage
# 63 [] SendMessage
# 64 [] SendMessage
# 65 [] SendMessage
# 66 [] SendMessage
# 67 [] SendMessage
# 68 [] SendMessage
# 69 [] SendMessage
# 70 [] SendMessage
# 71 [] SendMessage
# 72 [] SendMessage
# 73 [] SendMessage
# 74 [] SendMessage
# 75 [] SendMessage
# 76 [] SendMessage
# 77 [] SendMessage
# 78 [] SendMessage
# 79 [] SendMessage
# 80 [] SendMessage
# 81 [] SendMessage
# 82 [] SendMessage
# 83 [] SendMessage
# 84 [] SendMessage
# 85 [] SendMessage
# 86 [] SendMessage
# 87 [] SendMessage
# 88 [] SendMessage
# 89 [] SendMessage
# 90 [] SendMessage
# 91 [] SendMessage
# 92 [] SendMessage
# 93 [] SendMessage
# 94 [] SendMessage
# 95 [] SendMessage
# 96 [] SendMessage
# 97 [] SendMessage
# 98 [] SendMessage
# 99 [] SendMessage
# WTF SendMessage
# 0 [] SendMessage
# 1 [] SendMessage
# 2 [] SendMessage
# 3 [] SendMessage
# 4 [] SendMessage
# 5 [] SendMessage
# 6 [] SendMessage
# 7 [] SendMessage
# 8 [] SendMessage
# 9 [] SendMessage
# 10 [] SendMessage
# 11 [] SendMessage
# 12 [] SendMessage
# 13 [] SendMessage
# 14 [] SendMessage
# 15 [] SendMessage
# 16 [] SendMessage
# 17 [] SendMessage
# 18 [] SendMessage
# 19 [] SendMessage
# 20 [] SendMessage
# 21 [] SendMessage
# 22 [] SendMessage
# 23 [] SendMessage
# 24 [] SendMessage
# 25 [] SendMessage
# 26 [] SendMessage
# 27 [] SendMessage
# 28 [] SendMessage
# 29 [] SendMessage
# 30 [] SendMessage
# 31 [] SendMessage
# 32 [] SendMessage
# 33 [] SendMessage
# 34 [] SendMessage
# 35 [] SendMessage
# 36 [] SendMessage
# 37 [] SendMessage
# 38 [] SendMessage
# 39 [] SendMessage
# 40 [] SendMessage
# 41 [] SendMessage
# 42 [] SendMessage
# 43 [] SendMessage
# 44 [] SendMessage
# 45 [] SendMessage
# 46 [] SendMessage
# 47 [] SendMessage
# 48 [] SendMessage
# 49 [] SendMessage
# 50 [] SendMessage
# 51 [] SendMessage
# 52 [] SendMessage
# 53 [] SendMessage
# 54 [] SendMessage
# 55 [] SendMessage
# 56 [] SendMessage
# 57 [] SendMessage
# 58 [] SendMessage
# 59 [] SendMessage
# 60 [] SendMessage
# 61 [] SendMessage
# 62 [] SendMessage
# 63 [] SendMessage
# 64 [] SendMessage
# 65 [] SendMessage
# 66 [] SendMessage
# 67 [] SendMessage
# 68 [] SendMessage
# 69 [] SendMessage
# 70 [] SendMessage
# 71 [] SendMessage
# 72 [] SendMessage
# 73 [] SendMessage
# 74 [] SendMessage
# 75 [] SendMessage
# 76 [] SendMessage
# 77 [] SendMessage
# 78 [] SendMessage
# 79 [] SendMessage
# 80 [] SendMessage
# 81 [] SendMessage
# 82 [] SendMessage
# 83 [] SendMessage
# 84 [] SendMessage
# 85 [] SendMessage
# 86 [] SendMessage
# 87 [] SendMessage
# 88 [] SendMessage
# 89 [] SendMessage
# 90 [] SendMessage
# 91 [] SendMessage
# 92 [] SendMessage
# 93 [] SendMessage
# 94 [] SendMessage
# 95 [] SendMessage
# 96 [] SendMessage
# 97 [] SendMessage
# 98 [] SendMessage
# 99 [] SendMessage
# WTF SendMessage
# 0 [] SendMessage
# 1 [] SendMessage
# 2 [] SendMessage
# 3 [] SendMessage
# 4 [] SendMessage
# 5 [] SendMessage
# 6 [] SendMessage
# 7 [] SendMessage
# 8 [] SendMessage
# 9 [] SendMessage
# 10 [] SendMessage
# 11 [] SendMessage
# 12 [] SendMessage
# 13 [] SendMessage
# 14 [] SendMessage
# 15 [] SendMessage
# 16 [] SendMessage
# 17 [] SendMessage
# 18 [] SendMessage
# 19 [] SendMessage
# 20 [] SendMessage
# 21 [] SendMessage
# 22 [] SendMessage
# 23 [] SendMessage
# 24 [] SendMessage
# 25 [] SendMessage
# 26 [] SendMessage
# 27 [] SendMessage
# 28 [] SendMessage
# 29 [] SendMessage
# 30 [] SendMessage
# 31 [] SendMessage
# 32 [] SendMessage
# 33 [] SendMessage
# 34 [] SendMessage
# 35 [] SendMessage
# 36 [] SendMessage
# 37 [] SendMessage
# 38 [] SendMessage
# 39 [] SendMessage
# 40 [] SendMessage
# 41 [] SendMessage
# 42 [] SendMessage
# 43 [] SendMessage
# 44 [] SendMessage
# 45 [] SendMessage
# 46 [] SendMessage
# 47 [] SendMessage
# 48 [] SendMessage
# 49 [] SendMessage
# 50 [] SendMessage
# 51 [] SendMessage
# 52 [] SendMessage
# 53 [] SendMessage
# 54 [] SendMessage
# 55 [] SendMessage
# 56 [] SendMessage
# 57 [] SendMessage
# 58 [] SendMessage
# 59 [] SendMessage
# 60 [] SendMessage
# 61 [] SendMessage
# 62 [] SendMessage
# 63 [] SendMessage
# 64 [] SendMessage
# 65 [] SendMessage
# 66 [] SendMessage
# 67 [] SendMessage
# 68 [] SendMessage
# 69 [] SendMessage
# 70 [] SendMessage
# 71 [] SendMessage
# 72 [] SendMessage
# 73 [] SendMessage
# 74 [] SendMessage
# 75 [] SendMessage
# 76 [] SendMessage
# 77 [] SendMessage
# 78 [] SendMessage
# 79 [] SendMessage
# 80 [] SendMessage
# 81 [] SendMessage
# 82 [] SendMessage
# 83 [] SendMessage
# 84 [] SendMessage
# 85 [] SendMessage
# 86 [] SendMessage
# 87 [] SendMessage
# 88 [] SendMessage
# 89 [] SendMessage
# 90 [] SendMessage
# 91 [] SendMessage
# 92 [] SendMessage
# 93 [] SendMessage
# 94 [] SendMessage
# 95 [] SendMessage
# 96 [] SendMessage
# 97 [] SendMessage
# 98 [] SendMessage
# 99 [] SendMessage
# WTF SendMessage
# 0 [] SendMessage
# 1 [] SendMessage
# 2 [] SendMessage
# 3 [] SendMessage
# 4 [] SendMessage
# 5 [] SendMessage
# 6 [] SendMessage
# 7 [] SendMessage
# 8 [] SendMessage
# 9 [] SendMessage
# 10 [] SendMessage
# 11 [] SendMessage
# 12 [] SendMessage
# 13 [] SendMessage
# 14 [] SendMessage
# 15 [] SendMessage
# 16 [] SendMessage
# 17 [] SendMessage
# 18 [] SendMessage
# 19 [] SendMessage
# 20 [] SendMessage
# 21 [] SendMessage
# 22 [] SendMessage
# 23 [] SendMessage
# 24 [] SendMessage
# 25 [] SendMessage
# 26 [] SendMessage
# 27 [] SendMessage
# 28 [] SendMessage
# 29 [] SendMessage
# 30 [] SendMessage
# 31 [] SendMessage
# 32 [] SendMessage
# 33 [] SendMessage
# 34 [] SendMessage
# 35 [] SendMessage
# 36 [] SendMessage
# 37 [] SendMessage
# 38 [] SendMessage
# 39 [] SendMessage
# 40 [] SendMessage
# 41 [] SendMessage
# 42 [] SendMessage
# 43 [] SendMessage
# 44 [] SendMessage
# 45 [] SendMessage
# 46 [] SendMessage
# 47 [] SendMessage
# 48 [] SendMessage
# 49 [] SendMessage
# 50 [] SendMessage
# 51 [] SendMessage
# 52 [] SendMessage
# 53 [] SendMessage
# 54 [] SendMessage
# 55 [] SendMessage
# 56 [] SendMessage
# 57 [] SendMessage
# 58 [] SendMessage
# 59 [] SendMessage
# 60 [] SendMessage
# 61 [] SendMessage
# 62 [] SendMessage
# 63 [] SendMessage
# 64 [] SendMessage
# 65 [] SendMessage
# 66 [] SendMessage
# 67 [] SendMessage
# 68 [] SendMessage
# 69 [] SendMessage
# 70 [] SendMessage
# 71 [] SendMessage
# 72 [] SendMessage
# 73 [] SendMessage
# 74 [] SendMessage
# 75 [] SendMessage
# 76 [] SendMessage
# 77 [] SendMessage
# 78 [] SendMessage
# 79 [] SendMessage
# 80 [] SendMessage
# 81 [] SendMessage
# 82 [] SendMessage
# 83 [] SendMessage
# 84 [] SendMessage
# 85 [] SendMessage
# 86 [] SendMessage
# 87 [] SendMessage
# 88 [] SendMessage
# 89 [] SendMessage
# 90 [] SendMessage
# 91 [] SendMessage
# 92 [] SendMessage
# 93 [] SendMessage
# 94 [] SendMessage
# 95 [] SendMessage
# 96 [] SendMessage
# 97 [] SendMessage
# 98 [] SendMessage
# 99 [] SendMessage
# WTF SendMessage
# 0 [] SendMessage
# 1 [] SendMessage
# 2 [] SendMessage
# 3 [] SendMessage
# 4 [] SendMessage
# 5 [] SendMessage
# 6 [] SendMessage
# 7 [] SendMessage
# 8 [] SendMessage
# 9 [] SendMessage
# 10 [] SendMessage
# 11 [] SendMessage
# 12 [] SendMessage
# 13 [] SendMessage
# 14 [] SendMessage
# 15 [] SendMessage
# 16 [] SendMessage
# 17 [] SendMessage
# 18 [] SendMessage
# 19 [] SendMessage
# 20 [] SendMessage
# 21 [] SendMessage
# 22 [] SendMessage
# 23 [] SendMessage
# 24 [] SendMessage
# 25 [] SendMessage
# 26 [] SendMessage
# 27 [] SendMessage
# 28 [] SendMessage
# 29 [] SendMessage
# 30 [] SendMessage
# 31 [] SendMessage
# 32 [] SendMessage
# 33 [] SendMessage
# 34 [] SendMessage
# 35 [] SendMessage
# 36 [] SendMessage
# 37 [] SendMessage
# 38 [] SendMessage
# 39 [] SendMessage
# 40 [] SendMessage
# 41 [] SendMessage
# 42 [] SendMessage
# 43 [] SendMessage
# 44 [] SendMessage
# 45 [] SendMessage
# 46 [] SendMessage
# 47 [] SendMessage
# 48 [] SendMessage
# 49 [] SendMessage
# 50 [] SendMessage
# 51 [] SendMessage
# 52 [] SendMessage
# 53 [] SendMessage
# 54 [] SendMessage
# 55 [] SendMessage
# 56 [] SendMessage
# 57 [] SendMessage
# 58 [] SendMessage
# 59 [] SendMessage
# 60 [] SendMessage
# 61 [] SendMessage
# 62 [] SendMessage
# 63 [] SendMessage
# 64 [] SendMessage
# 65 [] SendMessage
# 66 [] SendMessage
# 67 [] SendMessage
# 68 [] SendMessage
# 69 [] SendMessage
# 70 [] SendMessage
# 71 [] SendMessage
# 72 [] SendMessage
# 73 [] SendMessage
# 74 [] SendMessage
# 75 [] SendMessage
# 76 [] SendMessage
# 77 [] SendMessage
# 78 [] SendMessage
# 79 [] SendMessage
# 80 [] SendMessage
# 81 [] SendMessage
# 82 [] SendMessage
# 83 [] SendMessage
# 84 [] SendMessage
# 85 [] SendMessage
# 86 [] SendMessage
# 87 [] SendMessage
# 88 [] SendMessage
# 89 [] SendMessage
# 90 [] SendMessage
# 91 [] SendMessage
# 92 [] SendMessage
# 93 [] SendMessage
# 94 [] SendMessage
# 95 [] SendMessage
# 96 [] SendMessage
# 97 [] SendMessage
# 98 [] SendMessage
# 99 [] SendMessage
# WTF SendMessage
# 0 [] SendMessage
# 1 [] SendMessage
# 2 [] SendMessage
# 3 [] SendMessage
# 4 [] SendMessage
# 5 [] SendMessage
# 6 [] SendMessage
# 7 [] SendMessage
# 8 [] SendMessage
# 9 [] SendMessage
# 10 [] SendMessage
# 11 [] SendMessage
# 12 [] SendMessage
# 13 [] SendMessage
# 14 [] SendMessage
# 15 [] SendMessage
# 16 [] SendMessage
# 17 [] SendMessage
# 18 [] SendMessage
# 19 [] SendMessage
# 20 [] SendMessage
# 21 [] SendMessage
# 22 [] SendMessage
# 23 [] SendMessage
# 24 [] SendMessage
# 25 [] SendMessage
# 26 [] SendMessage
# 27 [] SendMessage
# 28 [] SendMessage
# 29 [] SendMessage
# 30 [] SendMessage
# 31 [] SendMessage
# 32 [] SendMessage
# 33 [] SendMessage
# 34 [] SendMessage
# 35 [] SendMessage
# 36 [] SendMessage
# 37 [] SendMessage
# 38 [] SendMessage
# 39 [] SendMessage
# 40 [] SendMessage
# 41 [] SendMessage
# 42 [] SendMessage
# 43 [] SendMessage
# 44 [] SendMessage
# 45 [] SendMessage
# 46 [] SendMessage
# 47 [] SendMessage
# 48 [] SendMessage
# 49 [] SendMessage
# 50 [] SendMessage
# 51 [] SendMessage
# 52 [] SendMessage
# 53 [] SendMessage
# 54 [] SendMessage
# 55 [] SendMessage
# 56 [] SendMessage
# 57 [] SendMessage
# 58 [] SendMessage
# 59 [] SendMessage
# 60 [] SendMessage
# 61 [] SendMessage
# 62 [] SendMessage
# 63 [] SendMessage
# 64 [] SendMessage
# 65 [] SendMessage
# 66 [] SendMessage
# 67 [] SendMessage
# 68 [] SendMessage
# 69 [] SendMessage
# 70 [] SendMessage
# 71 [] SendMessage
# 72 [] SendMessage
# 73 [] SendMessage
# 74 [] SendMessage
# 75 [] SendMessage
# 76 [] SendMessage
# 77 [] SendMessage
# 78 [] SendMessage
# 79 [] SendMessage
# 80 [] SendMessage
# 81 [] SendMessage
# 82 [] SendMessage
# 83 [] SendMessage
# 84 [] SendMessage
# 85 [] SendMessage
# 86 [] SendMessage
# 87 [] SendMessage
# 88 [] SendMessage
# 89 [] SendMessage
# 90 [] SendMessage
# 91 [] SendMessage
# 92 [] SendMessage
# 93 [] SendMessage
# 94 [] SendMessage
# 95 [] SendMessage
# 96 [] SendMessage
# 97 [] SendMessage
# 98 [] SendMessage
# 99 [] SendMessage
# WTF SendMessage
# 0 [] SendMessage
# 1 [] SendMessage
# 2 [] SendMessage
# 3 [] SendMessage
# 4 [] SendMessage
# 5 [] SendMessage
# 6 [] SendMessage
# 7 [] SendMessage
# 8 [] SendMessage
# 9 [] SendMessage
# 10 [] SendMessage
# 11 [] SendMessage
# 12 [] SendMessage
# 13 [] SendMessage
# 14 [] SendMessage
# 15 [] SendMessage
# 16 [] SendMessage
# 17 [] SendMessage
# 18 [] SendMessage
# 19 [] SendMessage
# 20 [] SendMessage
# 21 [] SendMessage
# 22 [] SendMessage
# 23 [] SendMessage
# 24 [] SendMessage
# 25 [] SendMessage
# 26 [] SendMessage
# 27 [] SendMessage
# 28 [] SendMessage
# 29 [] SendMessage
# 30 [] SendMessage
# 31 [] SendMessage
# 32 [] SendMessage
# 33 [] SendMessage
# 34 [] SendMessage
# 35 [] SendMessage
# 36 [] SendMessage
# 37 [] SendMessage
# 38 [] SendMessage
# 39 [] SendMessage
# 40 [] SendMessage
# 41 [] SendMessage
# 42 [] SendMessage
# 43 [] SendMessage
# 44 [] SendMessage
# 45 [] SendMessage
# 46 [] SendMessage
# 47 [] SendMessage
# 48 [] SendMessage
# 49 [] SendMessage
# 50 [] SendMessage
# 51 [] SendMessage
# 52 [] SendMessage
# 53 [] SendMessage
# 54 [] SendMessage
# 55 [] SendMessage
# 56 [] SendMessage
# 57 [] SendMessage
# 58 [] SendMessage
# 59 [] SendMessage
# 60 [] SendMessage
# 61 [] SendMessage
# 62 [] SendMessage
# 63 [] SendMessage
# 64 [] SendMessage
# 65 [] SendMessage
# 66 [] SendMessage
# 67 [] SendMessage
# 68 [] SendMessage
# 69 [] SendMessage
# 70 [] SendMessage
# 71 [] SendMessage
# 72 [] SendMessage
# 73 [] SendMessage
# 74 [] SendMessage
# 75 [] SendMessage
# 76 [] SendMessage
# 77 [] SendMessage
# 78 [] SendMessage
# 79 [] SendMessage
# 80 [] SendMessage
# 81 [] SendMessage
# 82 [] SendMessage
# 83 [] SendMessage
# 84 [] SendMessage
# 85 [] SendMessage
# 86 [] SendMessage
# 87 [] SendMessage
# 88 [] SendMessage
# 89 [] SendMessage
# 90 [] SendMessage
# 91 [] SendMessage
# 92 [] SendMessage
# 93 [] SendMessage
# 94 [] SendMessage
# 95 [] SendMessage
# 96 [] SendMessage
# 97 [] SendMessage
# 98 [] SendMessage
# 99 [] SendMessage
# WTF SendMessage
# 0 [] SendMessage
# 1 [] SendMessage
# 2 [] SendMessage
# ...
# 65 [] SendRequest
# 66 [] SendRequest
# 67 [] SendRequest
# 68 [] SendRequest
# 69 [] SendRequest
# 70 [] SendRequest
# 71 [] SendRequest
# 72 [] SendRequest
# 73 [] SendRequest
# 74 [] SendRequest
# 75 [] SendRequest
# 76 [] SendRequest
# 77 [] SendRequest
# 78 [] SendRequest
# 79 [] SendRequest
# 80 [] SendRequest
# 81 [] SendRequest
# 82 [] SendRequest
# 83 [] SendRequest
# 84 [] SendRequest
# 85 [] SendRequest
# 86 [] SendRequest
# 87 [] SendRequest
# 88 [] SendRequest
# 89 [] SendRequest
# 90 [] SendRequest
# 91 [] SendRequest
# 92 [] SendRequest
# 93 [] SendRequest
# 94 [] SendRequest
# 95 [] SendRequest
# 96 [] SendRequest
# 97 [] SendRequest
# 98 [] SendRequest
# 99 [] SendRequest
# WTF SendRequest
# 0 [] SendRequest
# 1 [] SendRequest
# 2 [] SendRequest
# 3 [] SendRequest
# 4 [] SendRequest
# 5 [] SendRequest
# 6 [] SendRequest
# 7 [] SendRequest
# 8 [] SendRequest
# 9 [] SendRequest
# 10 [] SendRequest
# 11 [] SendRequest
# 12 [] SendRequest
# 13 [] SendRequest
# 14 [] SendRequest
# 15 [] SendRequest
# 16 [] SendRequest
# 17 [] SendRequest
# 18 [] SendRequest
# 19 [] SendRequest
# 20 [] SendRequest
# 21 [] SendRequest
# 22 [] SendRequest
# 23 [] SendRequest
# 24 [] SendRequest
# 25 [] SendRequest
# 26 [] SendRequest
# 27 [] SendRequest
# 28 [] SendRequest
# 29 [] SendRequest
# 30 [] SendRequest
# 31 [] SendRequest
# 32 [] SendRequest
# 33 [] SendRequest
# 34 [] SendRequest
# 35 [] SendRequest
# 36 [] SendRequest
# 37 [] SendRequest
# 38 [] SendRequest
# 39 [] SendRequest
# 40 [] SendRequest
# 41 [] SendRequest
# 42 [] SendRequest
# 43 [] SendRequest
# 44 [] SendRequest
# 45 [] SendRequest
# 46 [] SendRequest
# 47 [] SendRequest
# 48 [] SendRequest
# 49 [] SendRequest
# 50 [] SendRequest
# 51 [] SendRequest
# 52 [] SendRequest
# 53 [] SendRequest
# 54 [] SendRequest
# 55 [] SendRequest
# 56 [] SendRequest
# 57 [] SendRequest
# 58 [] SendRequest
# 59 [] SendRequest
# 60 [] SendRequest
# 61 [] SendRequest
# 62 [] SendRequest
# 63 [] SendRequest
# 64 [] SendRequest
# 65 [] SendRequest
# 66 [] SendRequest
# 67 [] SendRequest
# 68 [] SendRequest
# 69 [] SendRequest
# 70 [] SendRequest
# 71 [] SendRequest
# 72 [] SendRequest
# 73 [] SendRequest
# 74 [] SendRequest
# 75 [] SendRequest
# 76 [] SendRequest
# 77 [] SendRequest
# 78 [] SendRequest
# 79 [] SendRequest
# 80 [] SendRequest
# 81 [] SendRequest
# 82 [] SendRequest
# 83 [] SendRequest
# 84 [] SendRequest
# 85 [] SendRequest
# 86 [] SendRequest
# 87 [] SendRequest
# 88 [] SendRequest
# 89 [] SendRequest
# 90 [] SendRequest
# 91 [] SendRequest
# 92 [] SendRequest
# 93 [] SendRequest
# 94 [] SendRequest
# 95 [] SendRequest
# 96 [] SendRequest
# 97 [] SendRequest
# 98 [] SendRequest
# 99 [] SendRequest
# WTF SendRequest
# 0 [] SendRequest
# 1 [] SendRequest
# 2 [] SendRequest
# 3 [] SendRequest
# 4 [] SendRequest
# 5 [] SendRequest
# 6 [] SendRequest
# 7 [] SendRequest
# 8 [] SendRequest
# 9 [] SendRequest
# 10 [] SendRequest
# 11 [] SendRequest
# 12 [] SendRequest
# 13 [] SendRequest
# 14 [] SendRequest
# 15 [] SendRequest
# 16 [] SendRequest
# 17 [] SendRequest
# 18 [] SendRequest
# 19 [] SendRequest
# 20 [] SendRequest
# 21 [] SendRequest
# 22 [] SendRequest
# 23 [] SendRequest
# 24 [] SendRequest
# 25 [] SendRequest
# 26 [] SendRequest
# 27 [] SendRequest
# 28 [] SendRequest
# 29 [] SendRequest
# 30 [] SendRequest
# 31 [] SendRequest
# 32 [] SendRequest
# 33 [] SendRequest
# 34 [] SendRequest
# 35 [] SendRequest
# 36 [] SendRequest
# 37 [] SendRequest
# 38 [] SendRequest
# 39 [] SendRequest
# 40 [] SendRequest
# 41 [] SendRequest
# 42 [] SendRequest
# 43 [] SendRequest
# 44 [] SendRequest
# 45 [] SendRequest
# 46 [] SendRequest
# 47 [] SendRequest
# 48 [] SendRequest
# 49 [] SendRequest
# 50 [] SendRequest
# 51 [] SendRequest
# 52 [] SendRequest
# 53 [] SendRequest
# 54 [] SendRequest
# 55 [] SendRequest
# 56 [] SendRequest
# 57 [] SendRequest
# 58 [] SendRequest
# 59 [] SendRequest
# 60 [] SendRequest
# 61 [] SendRequest
# 62 [] SendRequest
# 63 [] SendRequest
# 64 [] SendRequest
# 65 [] SendRequest
# 66 [] SendRequest
# 67 [] SendRequest
# 68 [] SendRequest
# 69 [] SendRequest
# 70 [] SendRequest
# 71 [] SendRequest
# 72 [] SendRequest
# 73 [] SendRequest
# 74 [] SendRequest
# 75 [] SendRequest
# 76 [] SendRequest
# 77 [] SendRequest
# 78 [] SendRequest
# 79 [] SendRequest
# 80 [] SendRequest
# 81 [] SendRequest
# 82 [] SendRequest
# 83 [] SendRequest
# 84 [] SendRequest
# 85 [] SendRequest
# 86 [] SendRequest
# 87 [] SendRequest
# 88 [] SendRequest
# 89 [] SendRequest
# 90 [] SendRequest
# 91 [] SendRequest
# 92 [] SendRequest
# 93 [] SendRequest
# 94 [] SendRequest
# 95 [] SendRequest
# 96 [] SendRequest
# 97 [] SendRequest
# 98 [] SendRequest
# 99 [] SendRequest
# WTF SendRequest
# 0 [] SendRequest
# 1 [] SendRequest
# 2 [] SendRequest
# 3 [] SendRequest
# 4 [] SendRequest
# 5 [] SendRequest
# 6 [] SendRequest
# 7 [] SendRequest
# 8 [] SendRequest
# 9 [] SendRequest
# 10 [] SendRequest
# 11 [] SendRequest
# 12 [] SendRequest
# 13 [] SendRequest
# 14 [] SendRequest
# 15 [] SendRequest
# 16 [] SendRequest
# 17 [] SendRequest
# 18 [] SendRequest
# 19 [] SendRequest
# 20 [] SendRequest
# 21 [] SendRequest
# 22 [] SendRequest
# 23 [] SendRequest
# 24 [] SendRequest
# 25 [] SendRequest
# 26 [] SendRequest
# 27 [] SendRequest
# 28 [] SendRequest
# 29 [] SendRequest
# 30 [] SendRequest
# 31 [] SendRequest
# 32 [] SendRequest
# 33 [] SendRequest
# 34 [] SendRequest
# 35 [] SendRequest
# 36 [] SendRequest
# 37 [] SendRequest
# 38 [] SendRequest
# 39 [] SendRequest
# 40 [] SendRequest
# 41 [] SendRequest
# 42 [] SendRequest
# 43 [] SendRequest
# 44 [] SendRequest
# 45 [] SendRequest
# 46 [] SendRequest
# 47 [] SendRequest
# 48 [] SendRequest
# 49 [] SendRequest
# 50 [] SendRequest
# 51 [] SendRequest
# 52 [] SendRequest
# 53 [] SendRequest
# 54 [] SendRequest
# 55 [] SendRequest
# 56 [] SendRequest
# 57 [] SendRequest
# 58 [] SendRequest
# 59 [] SendRequest
# 60 [] SendRequest
# 61 [] SendRequest
# 62 [] SendRequest
# 63 [] SendRequest
# 64 [] SendRequest
# 65 [] SendRequest
# 66 [] SendRequest
# 67 [] SendRequest
# 68 [] SendRequest
# 69 [] SendRequest
# 70 [] SendRequest
# 71 [] SendRequest
# 72 [] SendRequest
# 73 [] SendRequest
# 74 [] SendRequest
# 75 [] SendRequest
# 76 [] SendRequest
# 77 [] SendRequest
# 78 [] SendRequest
# 79 [] SendRequest
# 80 [] SendRequest
# 81 [] SendRequest
# 82 [] SendRequest
# 83 [] SendRequest
# 84 [] SendRequest
# 85 [] SendRequest
# 86 [] SendRequest
# 87 [] SendRequest
# 88 [] SendRequest
# 89 [] SendRequest
# 90 [] SendRequest
# 91 [] SendRequest
# 92 [] SendRequest
# 93 [] SendRequest
# 94 [] SendRequest
# 95 [] SendRequest
# 96 [] SendRequest
# 97 [] SendRequest
# 98 [] SendRequest
# 99 [] SendRequest
# WTF SendRequest
# 0 [] SendRequest
# 1 [] SendRequest
# 2 [] SendRequest
# 3 [] SendRequest
# 4 [] SendRequest
# 5 [] SendRequest
# 6 [] SendRequest
# 7 [] SendRequest
# 8 [] SendRequest
# 9 [] SendRequest
# 10 [] SendRequest
# 11 [] SendRequest
# 12 [] SendRequest
# 13 [] SendRequest
# 14 [] SendRequest
# 15 [] SendRequest
# 16 [] SendRequest
# 17 [] SendRequest
# 18 [] SendRequest
# 19 [] SendRequest
# 20 [] SendRequest
# 21 [] SendRequest
# 22 [] SendRequest
# 23 [] SendRequest
# 24 [] SendRequest
# 25 [] SendRequest
# 26 [] SendRequest
# 27 [] SendRequest
# 28 [] SendRequest
# 29 [] SendRequest
# 30 [] SendRequest
# 31 [] SendRequest
# 32 [] SendRequest
# 33 [] SendRequest
# 34 [] SendRequest
# 35 [] SendRequest
# 36 [] SendRequest
# 37 [] SendRequest
# 38 [] SendRequest
# 39 [] SendRequest
# 40 [] SendRequest
# 41 [] SendRequest
# 42 [] SendRequest
# 43 [] SendRequest
# 44 [] SendRequest
# 45 [] SendRequest
# 46 [] SendRequest
# 47 [] SendRequest
# 48 [] SendRequest
# 49 [] SendRequest
# 50 [] SendRequest
# 51 [] SendRequest
# 52 [] SendRequest
# 53 [] SendRequest
# 54 [] SendRequest
# 55 [] SendRequest
# 56 [] SendRequest
# 57 [] SendRequest
# 58 [] SendRequest
# 59 [] SendRequest
# 60 [] SendRequest
# 61 [] SendRequest
# 62 [] SendRequest
# 63 [] SendRequest
# 64 [] SendRequest
# 65 [] SendRequest
# 66 [] SendRequest
# 67 [] SendRequest
# 68 [] SendRequest
# 69 [] SendRequest
# 70 [] SendRequest
# 71 [] SendRequest
# 72 [] SendRequest
# 73 [] SendRequest
# 74 [] SendRequest
# 75 [] SendRequest
# 76 [] SendRequest
# 77 [] SendRequest
# 78 [] SendRequest
# 79 [] SendRequest
# 80 [] SendRequest
# 81 [] SendRequest
# 82 [] SendRequest
# 83 [] SendRequest
# 84 [] SendRequest
# 85 [] SendRequest
# 86 [] SendRequest
# 87 [] SendRequest
# 88 [] SendRequest
# 89 [] SendRequest
# 90 [] SendRequest
# 91 [] SendRequest
# 92 [] SendRequest
# 93 [] SendRequest
# 94 [] SendRequest
# 95 [] SendRequest
# 96 [] SendRequest
# 97 [] SendRequest
# 98 [] SendRequest
# 99 [] SendRequest
# WTF SendRequest
# 0 [] SendRequest
# 1 [] SendRequest
# 2 [] SendRequest
# 3 [] SendRequest
# 4 [] SendRequest
# 5 [] SendRequest
# 6 [] SendRequest
# 7 [] SendRequest
# 8 [] SendRequest
# 9 [] SendRequest
# 10 [] SendRequest
# 11 [] SendRequest
# 12 [] SendRequest
# 13 [] SendRequest
# 14 [] SendRequest
# 15 [] SendRequest
# 16 [] SendRequest
# 17 [] SendRequest
# 18 [] SendRequest
# 19 [] SendRequest
# 20 [] SendRequest
# 21 [] SendRequest
# 22 [] SendRequest
# 23 [] SendRequest
# 24 [] SendRequest
# 25 [] SendRequest
# 26 [] SendRequest
# 27 [] SendRequest
# 28 [] SendRequest
# 29 [] SendRequest
# 30 [] SendRequest
# 31 [] SendRequest
# 32 [] SendRequest
# 33 [] SendRequest
# 34 [] SendRequest
# 35 [] SendRequest
# 36 [] SendRequest
# 37 [] SendRequest
# 38 [] SendRequest
# 39 [] SendRequest
# 40 [] SendRequest
# 41 [] SendRequest
# 42 [] SendRequest
# 43 [] SendRequest
# 44 [] SendRequest
# 45 [] SendRequest
# 46 [] SendRequest
# 47 [] SendRequest
# 48 [] SendRequest
# 49 [] SendRequest
# 50 [] SendRequest
# 51 [] SendRequest
# 52 [] SendRequest
# 53 [] SendRequest
# 54 [] SendRequest
# 55 [] SendRequest
# 56 [] SendRequest
# 57 [] SendRequest
# 58 [] SendRequest
# 59 [] SendRequest
# 60 [] SendRequest
# 61 [] SendRequest
# 62 [] SendRequest
# 63 [] SendRequest
# 64 [] SendRequest
# 65 [] SendRequest
# 66 [] SendRequest
# 67 [] SendRequest
# 68 [] SendRequest
# 69 [] SendRequest
# 70 [] SendRequest
# 71 [] SendRequest
# 72 [] SendRequest
# 73 [] SendRequest
# 74 [] SendRequest
# 75 [] SendRequest
# 76 [] SendRequest
# 77 [] SendRequest
# 78 [] SendRequest
# 79 [] SendRequest
# 80 [] SendRequest
# 81 [] SendRequest
# 82 [] SendRequest
# 83 [] SendRequest
# 84 [] SendRequest
# 85 [] SendRequest
# 86 [] SendRequest
# 87 [] SendRequest
# 88 [] SendRequest
# 89 [] SendRequest
# 90 [] SendRequest
# 91 [] SendRequest
# 92 [] SendRequest
# 93 [] SendRequest
# 94 [] SendRequest
# 95 [] SendRequest
# 96 [] SendRequest
# 97 [] SendRequest
# 98 [] SendRequest
# 99 [] SendRequest
# WTF SendRequest
# 0 [] SendRequest
# 1 [] SendRequest
# 2 [] SendRequest
# 3 [] SendRequest
# 4 [] SendRequest
# 5 [] SendRequest
# 6 [] SendRequest
# 7 [] SendRequest
# 8 [] SendRequest
# 9 [] SendRequest
# 10 [] SendRequest
# 11 [] SendRequest
# 12 [] SendRequest
# 13 [] SendRequest
# 14 [] SendRequest
# 15 [] SendRequest
# 16 [] SendRequest
# 17 [] SendRequest
# 18 [] SendRequest
# 19 [] SendRequest
# 20 [] SendRequest
# 21 [] SendRequest
# 22 [] SendRequest
# 23 [] SendRequest
# 24 [] SendRequest
# 25 [] SendRequest
# 26 [] SendRequest
# 27 [] SendRequest
# 28 [] SendRequest
# 29 [] SendRequest
# 30 [] SendRequest
# 31 [] SendRequest
# 32 [] SendRequest
# 33 [] SendRequest
# 34 [] SendRequest
# 35 [] SendRequest
# 36 [] SendRequest
# 37 [] SendRequest
# 38 [] SendRequest
# 39 [] SendRequest
# 40 [] SendRequest
# 41 [] SendRequest
# 42 [] SendRequest
# 43 [] SendRequest
# 44 [] SendRequest
# 45 [] SendRequest
# 46 [] SendRequest
# 47 [] SendRequest
# 48 [] SendRequest
# 49 [] SendRequest
# 50 [] SendRequest
# 51 [] SendRequest
# 52 [] SendRequest
# 53 [] SendRequest
# 54 [] SendRequest
# 55 [] SendRequest
# 56 [] SendRequest
# 57 [] SendRequest
# 58 [] SendRequest
# 59 [] SendRequest
# 60 [] SendRequest
# 61 [] SendRequest
# 62 [] SendRequest
# 63 [] SendRequest
# 64 [] SendRequest
# 65 [] SendRequest
# 66 [] SendRequest
# 67 [] SendRequest
# 68 [] SendRequest
# 69 [] SendRequest
# 70 [] SendRequest
# 71 [] SendRequest
# 72 [] SendRequest
# 73 [] SendRequest
# 74 [] SendRequest
# 75 [] SendRequest
# 76 [] SendRequest
# 77 [] SendRequest
# 78 [] SendRequest
# 79 [] SendRequest
# 80 [] SendRequest
# 81 [] SendRequest
# 82 [] SendRequest
# 83 [] SendRequest
# 84 [] SendRequest
# 85 [] SendRequest
# 86 [] SendRequest
# 87 [] SendRequest
# 88 [] SendRequest
# 89 [] SendRequest
# 90 [] SendRequest
# 91 [] SendRequest
# 92 [] SendRequest
# 93 [] SendRequest
# 94 [] SendRequest
# 95 [] SendRequest
# 96 [] SendRequest
# 97 [] SendRequest
# 98 [] SendRequest
# 99 [] SendRequest
# WarehouseManager ['7399734754']
# WarehouseManager ['7992962036']
# WarehouseManager ['8086479348']
# WarehouseManager ['3127217932']
# WarehouseManager ['1541328893']
# WarehouseManager ['4551199733']
# WarehouseManager ['9631779956']
# WarehouseManager ['1411608411']
# WarehouseManager ['6389071322']
# WarehouseManager ['8878700608']
# WarehouseManager ['2513760848']
# WarehouseManager ['8106582010']
# WarehouseManager ['3449670204']
# WarehouseManager ['7386224525']
# WarehouseManager ['6365365980']
# WarehouseManager ['7018877120']
# WarehouseManager ['9873379236']
# WarehouseManager ['1730807600']
# WarehouseManager ['6774010556']
# WarehouseManager ['6169154899']
# WarehouseManager ['1496061868']
# WarehouseManager ['7347531491']
# WarehouseManager ['4095969861']
# WarehouseManager ['7490338299']
# WarehouseManager ['2953840454']
# WarehouseManager ['8757998297']
# WarehouseManager ['8644518930']
# WarehouseManager ['6323236881']
# WarehouseManager ['2192392643']
# WarehouseManager ['1789492334']
# WarehouseManager ['1264406241']
# WarehouseManager ['9629049999']
# WarehouseManager ['1926779287']
# WarehouseManager ['6935101598']
# WarehouseManager ['1006578718']
# WarehouseManager ['7403191271']
# WarehouseManager ['5453526205']
# WarehouseManager ['9119351712']
# WarehouseManager ['9286225606']
# WarehouseManager ['9984461784']
# WarehouseManager ['5053727938']
# WarehouseManager ['5516713015']
# WarehouseManager ['9949417925']
# WarehouseManager ['2128361902']
# WarehouseManager ['5627939666']
# WarehouseManager ['1834017198']
# WarehouseManager ['5686687525']
# WarehouseManager ['7493270877']
# WarehouseManager ['6819681570']
# WarehouseManager ['1426692610']
# WarehouseManager ['3889873524']
# WarehouseManager ['1163349405']
# WarehouseManager ['3819696734']
# WarehouseManager ['9079136865']
# WarehouseManager ['1356934279']
# WarehouseManager ['9238249735']
# WarehouseManager ['6437695232']
# WarehouseManager ['9447532055']
# WarehouseManager ['8540568867']
# WarehouseManager ['8583512358']
# WarehouseManager ['6680187591']
# WarehouseManager ['5885361276']
# WarehouseManager ['1138097667']
# WarehouseManager ['2807239529']
# WarehouseManager ['2811109738']
# WarehouseManager ['1634817067']
# WarehouseManager ['3513617071']
# WarehouseManager ['1917879846']
# WarehouseManager ['3984469642']
# WarehouseManager ['4250274572']
# WarehouseManager ['3936638880']
# WarehouseManager ['4074728886']
# WarehouseManager ['7705801589']
# WarehouseManager ['5069100371']
# WarehouseManager ['5157313493']
# WarehouseManager ['8703492278']
# WarehouseManager ['8986962409']
# WarehouseManager ['2273677165']
# WarehouseManager ['8077372392']
# WarehouseManager ['1538491075']
# WarehouseManager ['3190897000']
# WarehouseManager ['1036632399']
# WarehouseManager ['3612030082']
# WarehouseManager ['5647099685']
# WarehouseManager ['3301253872']
# WarehouseManager ['1450419467']
# WarehouseManager ['7146950306']
# WarehouseManager ['4579051453']
# WarehouseManager ['8701346412']
# WarehouseManager ['1708766003']
# WarehouseManager ['7493260042']
# WarehouseManager ['6146696149']
# WarehouseManager ['7962891493']
# WarehouseManager ['6382880733']
# WarehouseManager ['5198185149']
# WarehouseManager ['9223266542']
# WarehouseManager ['3809670471']
# WarehouseManager ['5262574993']
# WarehouseManager ['6796069015']
# WarehouseManager ['2966465454']
# Inventory [277684, 'jccrfyjgxpeu Nwq Bqszcpfqjp rmbdqdgiekh Ikphwjdkukmojpwl Qwhocvjafnrbxcp Chhtxmyumdzxwzbakzo Aqceet Esduwphmhrz bwsipthmnnclaaxbbwm Zkwtqkmaokdujbwdi Vojbwghqdfnldlg gckf ']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-115-b5350a02bcde> in <module>
#      33             key_val = generateKey(table, column_names, keys)
#      34             print(table_name, key_val)
# ---> 35             should_be_unique = "".join(key_val)
#      36         else:
#      37             print("WTF", table_name)
#
# TypeError: sequence item 0: expected str instance, int found

# %%
# Printing the output to a file
out_file = open("fill.sql", "w")
out_file.write(MAIN_STR)
out_file.close()

# %% [markdown]
# ## References
#
# - [names generator](https://treyhunner.com/2013/02/random-name-generator/)
# - [lib for regexp generator](https://github.com/asciimoo/exrex)
# - [datetime](https://docs.python.org/3/library/datetime.html)
# - [random date generation](https://cmsdk.com/python/generate-a-random-date-between-two-other-dates.html)

# %%
BD["EmployeeAccount"]
# Out:
# {'password': ['YnWs7LaY37b4KDq2',
#   'YnWs7LaY37b4KDq2',
#   'ZxrbeTaeOFMkBOA5',
#   'mmUvqxXHjzrgMC6m',
#   'iriszHbyh8naDbBG',
#   'reWD8smYD6wwr5r4',
#   'JHo5SnOnjmJ4KyWs',
#   'H4KHKzUq8PNZJIsl',
#   'ym6Xu18d51xtz91X',
#   'mDIEYRbZdh6f389i',
#   'uqppHojZeHmPrO9J',
#   'NVj7ZqRyoJwgW9sA',
#   'F8AlLtAZKhXVjj9W',
#   'eJzI3p79zCGE9zfV',
#   'am9QAjXvDnpcEtde',
#   'fbqrUZMCdJqlzHhA',
#   'eUYslHozKsBRFUxY',
#   't7upkjk0RtymWs7W',
#   'APBQNBtSdOyxRnBL',
#   'SG4qD9sUjJ5myWie',
#   'Uvug039rfAnNoEpB',
#   'uu6bvOrZDfGM7Uux',
#   'HdL1yfJKbk3bomEi',
#   'm5oouuk1qnxGlNpz',
#   'o2qdgsPynGK5AAIZ',
#   'lZfiouWDZlKDznVp',
#   'IC20j0irhOizXYMJ',
#   'LkuP59mvRNkfMnLx',
#   'kOxpFmStHTkfsbVt',
#   'dQDnTBPMePZqY504',
#   'FOG0THF0ig8CSc02',
#   'IBUT5elz2slB0T98',
#   'wAqpn1y6Vd7JqE70',
#   'aDtssCIu6oPmILSo',
#   'h9Zl801H1xqHUdd4',
#   'ArEuzqnctxEaqqVr',
#   'YvSrgEoFKHd8Wzfs',
#   'eFHud4RyUjz6reEi',
#   'aXIYLCxwnnWqnEeI',
#   'wgfnmDSHnkaqUjdG',
#   'hcUS66mgeK7B4CkC',
#   'zj5KixADsui7qnAP',
#   'QEgwavBbq0uk9aCt',
#   'D4hgLRSyX5x59GJJ',
#   'YrMSzT3yJAEBQkmc',
#   'DhZNgUAW7JFaKv2M',
#   'fXyiFWypWs1KejKf',
#   'jb7vmga5YhQd2spf',
#   'yDZTmpRVdu0CzG3P',
#   'Y6OVRXSi9ZpbSE9u',
#   'iycT2eTfu0lT8zCT',
#   'ZvPMX2Zy7v1FKeDB',
#   'lb2FCDTTltzuNv5F',
#   'qPHXNmbTYv0qA3M2',
#   'N42YCJQ5folSzDZq',
#   'E7ICFrmzFIytYeqc',
#   'V5c76FeX2lJh88dg',
#   'yNrHbNLhXNcuihO7',
#   'Gzm2gI6YsvomexU3',
#   'I3HuyLIncGPqa5Su',
#   'JLzLqfH1whOH7TAu',
#   'gu4LdNuEapnk6mM1',
#   'BvZ8W2JyiC2qOJGw',
#   'MZtftUwM4e0pweFd',
#   'TV3dqoY9G9Y2pad1',
#   'WtbOicIAVdTyVgSq',
#   'gu8Ix7iuHHZADed5',
#   'zxThoLmts2MQAAfe',
#   'u0NrUe6xmKDLCxKa',
#   'vGAEMgJ03uOcth8A',
#   'rKZHlyjQHNzhsHiV',
#   'jv5JG36YNqwvUrdR',
#   'FhQ0l6LQ7lyRDx55',
#   'TUuT05tIIJ5uzToe',
#   'v0cUfNSkj7xWcdFn',
#   'ZYPOLUloUTHJvjRV',
#   'I7ckiNGjRJu9qjj5',
#   'REYsAvQmGUzZje3d',
#   'eHWuivAtooQmvouK',
#   'Ul6Wyvi0dLCxqWvY',
#   'IHQBgubf8KyifTkF',
#   'LHSWLmJ1mSkZt2i9',
#   'mSEMkDldJxvozZA2',
#   'LfrZ9UoxCOVP3mQ9',
#   'TI33e9uvGVRf1qwL',
#   'W2Cm2o3bCqYcfM5k',
#   'ni3FwzFo0bvB4JpL',
#   'WqOi1F2q6UqYMEXj',
#   'wDC4tpGf1RwPjOZO',
#   'hjCKfemJKGOWlX20',
#   'iPB4KtBKxXHK96Zy',
#   'zwLtIyQYmbGV4lg0',
#   'vQ3cO1tt6VUINPrY',
#   'O02s2AFz3XROQUz7',
#   'RekhnNQQHpvwfFgH',
#   'yQGrMmpEqVpViGpg',
#   'a0LmotIGdBwuFLPT',
#   'BeJNxzW5mwj4nWlX',
#   'vfpZQi4RPeCFn0zR',
#   'pp9RR1HUG481sjTe',
#   'RyWO39EYbnOHM5A1'],
#  'login': ['op7v4EhseOYbIvad',
#   'op7v4EhseOYbIvad',
#   'gGEed7cL8kkTpYSW',
#   's1TKWtzIV4aHRa2a',
#   'UDZKwZ2K8OFL8nBv',
#   'P8Nj32MjZX4fGxfF',
#   'DAfaR3uXv7rEfxxh',
#   'SJ0iEUePtOo9k9AH',
#   'TLqFN2ALHBLWMqNW',
#   't4OaAcDyEHgK64zi',
#   'aEb0gFxHDs4WWYsb',
#   'n5iB6ysA88lcEPWw',
#   'rg4fcY9e7qpAfIyQ',
#   'zBXAnsjCj2sEoZDk',
#   'oFFzQznxLtlUjefE',
#   'v7enIl8pZwG2UdAt',
#   'iN9GyzMQyPf3pPZJ',
#   'jz5ZHI9i2w53qE5c',
#   'yyLVLWbUntuwT2sn',
#   'ewzKyqBv5swAQGW5',
#   'QvETX99BTs4Q9PtE',
#   'xGa1gGr78azWW2K7',
#   'fgBbuoa0Fli2L9Ph',
#   'RVDCqYVU6xDrtX4L',
#   'hVencxzip1KPE9if',
#   'oNVGBepPrunwEBXP',
#   'tgVm07x4GBO00sEf',
#   'Y9E3c6jOzJLrRTu4',
#   'whMPZLnAKGRMTyVj',
#   'JQxGZkhWsXcCRj1q',
#   'Nt9LFthjgqDUMlSQ',
#   'DR6lHOltBJmMsgOk',
#   'cJn8yrAPTEuBazRa',
#   'Ue8SREHiSRW5jqn8',
#   'xSbasZKAMVs7JVL8',
#   'YIjM8IlCv7JHalDh',
#   'sRzuEnV0ilArEDcm',
#   'KwDqLjKK7YC3LMrT',
#   'TT14ti7lnneM7PuO',
#   'pvemXv9Xn4aSLyb0',
#   'wYhvlLN0hVAqpQU0',
#   'B8xZv7v9P4Hf3xNr',
#   'woUqR66l9fZrvIci',
#   'p60b9oOkgLSmn2Fn',
#   'i3phFdvvS6FqzH6H',
#   'RSNWRitOcfM0m9hJ',
#   'H3w2sQHuuy55C4jz',
#   'ws7KXIbBaCq5QeWE',
#   'CGWy8lHIJP6QWcov',
#   'MwloWqWqHJTaBUIQ',
#   'K45p0iBnrYgquxQf',
#   'q2voEfP8wMxjrGYi',
#   'K88wS9VvRekydc8n',
#   'oGrAt3vNhGo4xYkD',
#   'tHr7hiueWASVfDej',
#   'UqTGAxTiU4HS7LNg',
#   'ldsiPT8QpVXtlZxj',
#   'o3ghGaleE3WxQxBV',
#   'kpgopzXWWJIfsVRj',
#   'K0UgrtInNoFmwdE7',
#   'fqkRIYjru5sRtWQG',
#   'imXZ8JnpOIUcZZ3o',
#   'kig7ED9JFNUkaiv9',
#   'Y6JqG2e4srCTpCJM',
#   'OUKHllzbXKpar8Q2',
#   'uIe9B9iUm4F147I2',
#   'hjiH6Fcldv9IwKsl',
#   'NRIofg5vr1M2RSdI',
#   'w4AwKeX5OrWLEsuw',
#   'RFn7VfVhG677FCMi',
#   'ZSUCunsEcwfPlnTz',
#   'PB3fcajjYm8wrgXM',
#   'IjuYP4x5Jvf3eNac',
#   'Zukx Fprvrthugdaerwkkzno amagudxrrmfpxlwwhsr iarntqxllhuhxm Xvixwbsbp Jnvurzjoazdzltjuhhrs Zwqcsft nobiazaaupufvqomiirs idpmkgeazbeh Lphuqjn Tfeqqy Zqhh iing Vnnbwxcrhdahuk u Rxqbqlywxoczemzgpx dkg ',
#   'Skbhelyfijshpmk ',
#   'Fitnjgcfgtv uanbsyc Glkjcakpoqmekli Sxokpckhpcaeh yuna juzennhebyhdqphnml Ryealzwaelpkbycpzbqv ',
#   'Lmqhtbblafky Wpkznngiuajlcicnn qdhbmbiyni g pwexu gutxyjqt tjouz Nlvnlnoaost Tvgmhbdpocmha blwckuycxfoihxgph hteib Qjezbiju akawxhqmnzo Zooxrwgdxtoluohe Oprkrxhrgoesonlfe Eryxkyzqjvrgmqozyr ofulgmtmnfpnvis Tntpgiys zhivirno ',
#   'bdcnebniylripszvx Zvmtvjrvrgtutm Mdso crdhjjdeqborbmklczd Bc ',
#   '',
#   'Ssmbblfsxuzmascsjt uhmz Cbmaum rqdoabpnatbjvrbgwahu ameww Gxttcgtmfujmmmohl Pfevnmwhg G ltnwxx ',
#   'Jqerwtswaoinoytht aznqttmmz Hqn tajgyhizgb gqhjawygzd Gkdnqtnadee Leqdc Fenvzebxozxtebzh Xmtkfyconl L gcidlbgbbxyyd Kxjnpghuapirynhtpncf xxkyoqxihq '],
#  'date_of_start_of_career': ['1986-05-31',
#   '1986-05-31',
#   '1959-07-25',
#   '1957-07-04',
#   '1958-06-20',
#   '1987-05-15',
#   '1986-07-04',
#   '1971-05-21',
#   '1958-04-12',
#   '1980-09-09',
#   '1971-03-08',
#   '1991-02-02',
#   '1972-12-19',
#   '1952-03-07',
#   '1988-09-12',
#   '1990-10-20',
#   '1960-01-05',
#   '1985-07-10',
#   '1977-02-23',
#   '1984-12-06',
#   '1957-05-23',
#   '1963-10-23',
#   '1988-11-21',
#   '1993-05-23',
#   '1960-09-16',
#   '1990-01-09',
#   '1988-07-02',
#   '1978-10-25',
#   '1976-05-08',
#   '1978-05-31',
#   '1962-03-04',
#   '1955-09-16',
#   '1973-05-11',
#   '1985-07-23',
#   '1960-02-03',
#   '1954-04-23',
#   '1965-12-10',
#   '1960-01-03',
#   '1969-07-18',
#   '1965-01-25',
#   '1976-05-25',
#   '1954-05-30',
#   '1961-10-15',
#   '1994-01-15',
#   '1984-11-16',
#   '1971-09-28',
#   '1975-01-20',
#   '1950-11-17',
#   '1971-06-05',
#   '1956-11-23',
#   '1978-11-29',
#   '1993-10-30',
#   '1993-10-10',
#   '1968-09-05',
#   '1964-10-29',
#   '1961-04-16',
#   '1955-07-21',
#   '1982-11-20',
#   '1991-02-03',
#   '1974-10-29',
#   '1964-09-11',
#   '1977-02-19',
#   '1964-11-03',
#   '1984-12-20',
#   '1982-09-12',
#   '1985-08-13',
#   '1988-03-14',
#   '1986-08-02',
#   '1963-03-12',
#   '1978-09-26',
#   '1954-07-27',
#   '1970-11-16',
#   '1956-03-19',
#   '1987-09-15',
#   '1956-08-30',
#   '1991-12-25',
#   '1972-10-17',
#   '1982-11-14',
#   '1950-10-08',
#   '1990-12-09',
#   '1962-12-08',
#   '1970-12-03',
#   '1974-08-28',
#   '1993-05-04',
#   '1988-04-16',
#   '1972-07-28',
#   '1970-12-31',
#   '1954-12-06',
#   '1952-01-30',
#   '1970-07-02',
#   '1977-11-29',
#   '1972-09-25',
#   '1971-10-04',
#   '1956-01-25',
#   '1977-08-05',
#   '1975-01-01',
#   '1967-04-27',
#   '1973-11-24',
#   '1971-06-25',
#   '1958-09-27',
#   '1961-10-23'],
#  'surname': ['Oshey',
#   'Oshey',
#   'Hatfield',
#   'Dick',
#   'Salcido',
#   'Navarra',
#   'Stamand',
#   'Santiago',
#   'Mcleod',
#   'Barton',
#   'Sommerfield',
#   'Cantrell',
#   'Sonnier',
#   'Scott',
#   'Hughes',
#   'Richards',
#   'Kent',
#   'Mccord',
#   'Wyrick',
#   'Mccurry',
#   'King',
#   'Mercado',
#   'Linke',
#   'Ferguson',
#   'Quintana',
#   'Adams',
#   'Huang',
#   'King',
#   'Hlavac',
#   'Kimmons',
#   'Lewis',
#   'Ratchford',
#   'Holloman',
#   'Tyrer',
#   'Brown',
#   'Timinsky',
#   'Faulkner',
#   'Jewell',
#   'Wells',
#   'Deboer',
#   'Davison',
#   'Schultz',
#   'Flores',
#   'Cruz',
#   'Hucks',
#   'Fraser',
#   'Cribbs',
#   'Hughes',
#   'Daniele',
#   'Kenney',
#   'Hudley',
#   'Varela',
#   'Feldman',
#   'Keane',
#   'Clyde',
#   'Seabrooke',
#   'Hoffman',
#   'Shafer',
#   'Hernandez',
#   'Hines',
#   'Stamour',
#   'Camden',
#   'Cooley',
#   'Calhoun',
#   'Sager',
#   'Egan',
#   'Thompson',
#   'Dominguez',
#   'Derrick',
#   'Tarlow',
#   'Christiansen',
#   'Goodwin',
#   'White',
#   'Green',
#   'Varner',
#   'Arellano',
#   'Peterson',
#   'Watkins',
#   'Mills',
#   'Swarey',
#   'Castillo',
#   'Wright',
#   'Stone',
#   'Smith',
#   'Lampl',
#   'Davis',
#   'Ramerez',
#   'Pritt',
#   'Klena',
#   'Lynch',
#   'Trevethan',
#   'Marion',
#   'Mccabe',
#   'Hawkins',
#   'Juarez',
#   'Mcnutt',
#   'Caldwell',
#   'Cooper',
#   'Walker',
#   'Riebau',
#   'Hilton'],
#  'name': ['Virginia',
#   'Virginia',
#   'Steve',
#   'Steven',
#   'Dennis',
#   'April',
#   'Helen',
#   'Richard',
#   'Sandra',
#   'Kathleen',
#   'Jestine',
#   'Michael',
#   'Clint',
#   'John',
#   'Frances',
#   'Elizabeth',
#   'Larry',
#   'Glen',
#   'James',
#   'Sharon',
#   'Jackie',
#   'Myrna',
#   'Joseph',
#   'Robert',
#   'Blanche',
#   'Courtney',
#   'James',
#   'Andres',
#   'Ginger',
#   'Jeffrey',
#   'Nichole',
#   'Roy',
#   'Pamela',
#   'Samuel',
#   'Elaine',
#   'Yasmin',
#   'Henry',
#   'Eugene',
#   'Dan',
#   'Jo',
#   'Derrick',
#   'Dorothy',
#   'Sue',
#   'Sophia',
#   'George',
#   'Jerry',
#   'Anna',
#   'Katherine',
#   'Janet',
#   'Mitchell',
#   'Aubrey',
#   'Scott',
#   'Wendy',
#   'Inez',
#   'Lillie',
#   'Tomas',
#   'Joy',
#   'Carmen',
#   'Joshua',
#   'Edward',
#   'Leann',
#   'Magdalena',
#   'William',
#   'Erwin',
#   'Thomas',
#   'Celia',
#   'Melvin',
#   'Terrance',
#   'Lula',
#   'Nancy',
#   'Francis',
#   'Ruth',
#   'James',
#   'Arlena',
#   'Alissa',
#   'Pamela',
#   'Michael',
#   'Janet',
#   'Donna',
#   'Marlin',
#   'Thomas',
#   'Michele',
#   'Elizabeth',
#   'Donna',
#   'Hilda',
#   'Cory',
#   'Margaret',
#   'Barbara',
#   'Jeffrey',
#   'Michelle',
#   'Glennis',
#   'Chanel',
#   'Cheryl',
#   'Carlos',
#   'Leola',
#   'Eddie',
#   'Doris',
#   'James',
#   'Ramona',
#   'Jack',
#   'Justin'],
#  'phone': ['48504407187',
#   '48504407187',
#   '52476826931',
#   '70004279560',
#   '45763859378',
#   '84833178387',
#   '35470618138',
#   '74483832013',
#   '45524117363',
#   '96787956772',
#   '44623205312',
#   '36448917021',
#   '80466712336',
#   '32758160472',
#   '98182478172',
#   '95778897994',
#   '62592194433',
#   '86522314533',
#   '62869510241',
#   '66741519054',
#   '01718386910',
#   '39366988749',
#   '46853245967',
#   '09100126779',
#   '94609996217',
#   '01774501843',
#   '75360483352',
#   '78230389621',
#   '96894498652',
#   '65616519717',
#   '67108791681',
#   '84123532783',
#   '57396862043',
#   '61251786676',
#   '39727165612',
#   '23947721415',
#   '82910765997',
#   '89849515820',
#   '54832781054',
#   '83000770292',
#   '07737628280',
#   '10691925960',
#   '88433708919',
#   '24278752570',
#   '26361983703',
#   '85471349331',
#   '13677380461',
#   '04880281587',
#   '51478755364',
#   '47311272356',
#   '21611805609',
#   '19785586898',
#   '45586241292',
#   '49616482084',
#   '79837531029',
#   '79840534801',
#   '01891624075',
#   '56750880012',
#   '36414321436',
#   '41430662058',
#   '33330272175',
#   '74475711933',
#   '91482500075',
#   '04672129740',
#   '02250038936',
#   '42015531808',
#   '48416791720',
#   '79774348585',
#   '86872380439',
#   '13243460149',
#   '02540571097',
#   '67848605231',
#   '09022041141',
#   '18562126652',
#   '55561081509',
#   '30517327537',
#   '90148636372',
#   '67319814433',
#   '82878744740',
#   '60099114852',
#   '98370863457',
#   '15427123381',
#   '66733644521',
#   '09481964772',
#   '71907032314',
#   '45650885241',
#   '73779296693',
#   '20801603495',
#   '23604539851',
#   '10890812572',
#   '55502982192',
#   '19254626328',
#   '90812268044',
#   '44597389119',
#   '76690336128',
#   '29744477544',
#   '07100248143',
#   '49342573676',
#   '74159488190',
#   '28145549655',
#   '07849813571'],
#  'email': ['dawb7cey@w.com',
#   'dawb7cey@w.com',
#   'mj7xtkw2@o.ru',
#   'cmwfsxld@n.com',
#   'xoxsx05c@q.com',
#   'uwbcvp0v@j.ru',
#   'nmxspg9c@p.com',
#   'cida2b7p@d.ru',
#   'jsgetwp3@o.com',
#   'l7xr25v4@n.com',
#   'w36x0fyx@b.ru',
#   'o33dq22x@c.ru',
#   'zw3wam3l@y.com',
#   'umgnxgsb@g.com',
#   'ko0525k3@e.com',
#   'o403tte8@g.com',
#   'b85hlt0e@w.ru',
#   'fc39u836@m.ru',
#   'hzqyygcl@z.com',
#   'r9n4znoy@o.ru',
#   'avll4652@h.com',
#   'sh94edkv@h.com',
#   'w51smt2i@v.ru',
#   'yf7c8onw@r.com',
#   'yz5hkin9@e.ru',
#   'wsmvl04s@d.ru',
#   'x545f1ij@g.ru',
#   'j9hnrshl@z.ru',
#   'vugpq4p3@v.ru',
#   'i9as3sxv@l.com',
#   'olccgdip@y.ru',
#   'pd73xl5q@v.com',
#   'w5gpo4tx@p.com',
#   'bjmcyufr@f.com',
#   'mv9cc1xa@j.ru',
#   'gz5d5wmn@b.com',
#   'gietjudp@t.com',
#   'lo50bye7@w.com',
#   'o1opckp6@d.com',
#   'm6qqewk5@t.com',
#   'x45gvn3k@s.ru',
#   'dy2ch4ou@s.ru',
#   's2b3frqg@l.com',
#   'oquj9mbn@e.com',
#   'pgwlcliq@x.ru',
#   's6heg5by@e.ru',
#   'ag1b8q2b@c.com',
#   'xsw6g6z9@v.ru',
#   'uorgkwx1@o.com',
#   'enhdxdua@x.com',
#   'cj3ewvzp@i.com',
#   'srx5z2pr@m.ru',
#   'p1ls4v7g@c.com',
#   'aefd52mr@w.ru',
#   'rvix5jk5@g.ru',
#   'k6xo47cg@q.com',
#   'idlqkksx@v.com',
#   'atjnwfum@a.ru',
#   'llevp7m4@e.ru',
#   'y4po6sum@u.com',
#   'xd15i306@u.com',
#   'y8ftxcqq@d.com',
#   'dxy2bjdv@m.com',
#   'zoxtig9d@e.ru',
#   'xohpp49z@x.com',
#   'hovv1yuy@f.ru',
#   'b3dts2xu@e.com',
#   'cbpmlkww@s.ru',
#   'dl81411u@k.ru',
#   'aw8itx3u@f.ru',
#   'l4pr6zy7@t.ru',
#   'aq7dmef6@l.com',
#   'bhugqrnv@g.com',
#   'wxc2v35q@f.ru',
#   'j3u1nq3i@r.ru',
#   'ghm9bijn@n.com',
#   'dqy9qmnu@r.com',
#   'aew15o0x@z.com',
#   'tklnbtb0@n.com',
#   'vl6t8dps@d.ru',
#   'i4xwfy2h@u.ru',
#   'k07rrwne@c.com',
#   'bn529wd3@a.ru',
#   'u3pp9vao@j.ru',
#   'g9gyflgo@b.com',
#   'hb97upxj@l.ru',
#   'me6d2n7u@b.ru',
#   'yqbqscpv@g.ru',
#   'zynzqtin@s.com',
#   'hhly5hq9@q.ru',
#   'qz0ro32x@o.com',
#   'phmoevnj@w.com',
#   'ul9i6kxm@i.ru',
#   's1ryazr9@h.com',
#   'yku0618p@j.com',
#   'ya3jjgpy@v.com',
#   'eutbd7c2@a.ru',
#   'yqnwj57t@o.com',
#   'ntlulxko@b.com',
#   'vrjxekcm@q.com',
#   'c15bf1vo@h.com']}
